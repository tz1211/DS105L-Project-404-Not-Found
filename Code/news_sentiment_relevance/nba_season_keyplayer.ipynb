# %%
import requests

import pandas as pd

from bs4 import BeautifulSoup

from datetime import datetime

# %%
df600 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_author_credit/nba_600_credit_season_3.csv')
df1200 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_author_credit/nba_1200_credit_season_3.csv')
df1600 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_author_credit/nba_1600_credit_season_3.csv')

# %%
df_2022 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2015_player_data.csv')
df_2021 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2014_player_data.csv')
df_2020 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2013_player_data.csv')
df_2019 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2012_player_data.csv')
df_2018 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2011_player_data.csv')
df_2017 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2010_player_data.csv')
df_2016 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2016_player_data.csv')
df_2015 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2015_player_data.csv')
df_2014 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2014_player_data.csv')
df_2013 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2013_player_data.csv')
df_2012 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2012_player_data.csv')
df_2011 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2011_player_data.csv')
df_2010 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2010_player_data.csv')

# %%
nba_all = pd.concat([df600, df1200, df1600])

# %%
nba_all
# Out:
#       Unnamed: 0                                              title     time  \
# 0           1129           NBA Suspends Season Until Further Notice  2019-20
# 1           1130  Giannis Antetokounmpo Feared His Knee Injury W...  2019-20
# 2           1131          Warriors Statement On Chase Center Events  2019-20
# 3           1132                  4 NBA Things To Know For March 11  2019-20
# 4           1133  Lakers Miss Late Opportunity, Nets Take 104-10...  2019-20
# ...          ...                                                ...      ...
# 3024        4326  Carl Landry: Out until January with torn wrist...  2015-16
# 3025        4327  As he receives first NBA championship ring, Al...  2015-16
# 3026        4328  In facing LeBron, story often same as it ever ...  2015-16
# 3027        4329  NBA and Turner Sports to deliver first live ga...  2015-16
# 3028        4330  70 things we can’t wait to see in NBA’s 70th s...  2015-16
#
# ...

# %%
# 2019-20
nba_2019 = nba_all[nba_all["time"] == "2019-20"].copy()

# %%
import pandas as pd

def find_most_frequent_name(df, player_names):
    frequency_counts = []
    for index, row in df.iterrows():
        content = row['content']
        frequencies = [content.lower().count(name.lower()) for name in player_names]
        max_frequency_index = max(range(len(frequencies)), key=frequencies.__getitem__)
        most_frequent_name = player_names[max_frequency_index]
        frequency_counts.append(most_frequent_name)
    df['most_frequent_name'] = frequency_counts
    return df

# Example usage
player_names = ['LeBron James', 'Stephen Curry', 'Kevin Durant']
df_with_name = find_most_frequent_name(df, player_names)
