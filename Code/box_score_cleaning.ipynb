# %%
import pandas as pd

# %% [markdown]
# # Importing Data

# %% [markdown]
# ## Importing Box Score Data

# %%
df_all = pd.read_csv("../Data/merged_player_data_2010_2023.csv") 
df_all.drop(df_all.columns[df_all.columns.str.contains("Unnamed")], axis = 1, inplace = True) 
df_all["year"] = df_all["year"].apply(lambda x: int(x[:4])) 
df_all.drop("positions", axis = 1, inplace = True)
df_all
# Out:
#       year                     name  minutes_played  games_played  points  \
# 0     2023             Jayson Tatum            2508            67    2008
# 1     2023              Joel Embiid            2030            58    1946
# 2     2023  Shai Gilgeous-Alexander            2135            60    1884
# 3     2023              Luka Dončić            2068            57    1879
# 4     2023            Julius Randle            2623            73    1869
# ...    ...                      ...             ...           ...     ...
# 1428  2010            Allen Iverson             798            25     348
# 1429  2010             Marcus Camby             718            23     162
# 1430  2010          Stephen Jackson             300             9     149
# 1431  2010              Earl Barron             232             7      82
# 1432  2010                Raja Bell             157             5      60
#
#                         team  age  assists  attempted_field_goals  \
# 0             BOSTON CELTICS   24      317                   1424
# 1         PHILADELPHIA 76ERS   28      238                   1186
# 2      OKLAHOMA CITY THUNDER   24      330                   1222
# 3           DALLAS MAVERICKS   23      458                   1257
# 4            NEW YORK KNICKS   28      299                   1372
# ...                      ...  ...      ...                    ...
# 1428      PHILADELPHIA 76ERS   34      102                    290
# 1429  PORTLAND TRAIL BLAZERS   35       35                    145
# 1430   GOLDEN STATE WARRIORS   31       42                    133
# 1431         NEW YORK KNICKS   28        8                     68
# 1432       CHARLOTTE BOBCATS   33       10                     55
#
#       attempted_free_throws  ...  defensive_rebounds  games_started  \
# 0                       568  ...                 524             67
# 1                       691  ...                 490             58
# 2                       646  ...                 233             60
# 3                       629  ...                 443             57
# 4                       515  ...                 604             73
# ...                     ...  ...                 ...            ...
# 1428                    119  ...                  60             24
# 1429                     31  ...                 172             23
# 1430                     37  ...                  29              9
# 1431                     29  ...                  46              6
# 1432                      3  ...                  16              5
#
#       made_field_goals  made_free_throws  made_three_point_field_goals  \
# 0                  651               488                           218
# 1                  647               591                            61
# 2                  624               584                            52
# 3                  629               463                           158
# 4                  633               391                           212
# ...                ...               ...                           ...
# 1428               121                98                             8
# 1429                72                18                             0
# 1430                56                26                            11
# 1431                30                22                             0
# 1432                24                 3                             9
#
#       offensive_rebounds  personal_fouls       slug  steals turnovers
# 0                     73             144  tatumja01      68       198
# 1                    105             186  embiijo01      62       201
# 2                     54             163  gilgesh01     102       173
# 3                     48             148  doncilu01      83       209
# 4                    139             223  randlju01      47       208
# ...                  ...             ...        ...     ...       ...
# 1428                  15              43  iversal01      18        57
# 1429                  83              56  cambyma01      26        27
# 1430                   6              16  jacksst02      14        26
# 1431                  31              24  barroea01       4        11
# 1432                   5              13   bellra01       4         5
#
# [1433 rows x 22 columns]

# %%
targets = ["year", "slug", "name", "team", "age", "games_played"] 
targets = targets[::-1]
cols = list(df_all.columns)
for col in targets: 
    cols.insert(0, cols.pop(cols.index(col))) 
df_all = df_all.loc[:, cols]
df_all.rename(columns = {"year": "season"}, inplace = True)
df_all
# Out:
#       season       slug                     name                    team  age  \
# 0       2023  tatumja01             Jayson Tatum          BOSTON CELTICS   24
# 1       2023  embiijo01              Joel Embiid      PHILADELPHIA 76ERS   28
# 2       2023  gilgesh01  Shai Gilgeous-Alexander   OKLAHOMA CITY THUNDER   24
# 3       2023  doncilu01              Luka Dončić        DALLAS MAVERICKS   23
# 4       2023  randlju01            Julius Randle         NEW YORK KNICKS   28
# ...      ...        ...                      ...                     ...  ...
# 1428    2010  iversal01            Allen Iverson      PHILADELPHIA 76ERS   34
# 1429    2010  cambyma01             Marcus Camby  PORTLAND TRAIL BLAZERS   35
# 1430    2010  jacksst02          Stephen Jackson   GOLDEN STATE WARRIORS   31
# 1431    2010  barroea01              Earl Barron         NEW YORK KNICKS   28
# 1432    2010   bellra01                Raja Bell       CHARLOTTE BOBCATS   33
#
#       games_played  minutes_played  points  assists  attempted_field_goals  \
# 0               67            2508    2008      317                   1424
# 1               58            2030    1946      238                   1186
# 2               60            2135    1884      330                   1222
# 3               57            2068    1879      458                   1257
# 4               73            2623    1869      299                   1372
# ...            ...             ...     ...      ...                    ...
# 1428            25             798     348      102                    290
# 1429            23             718     162       35                    145
# 1430             9             300     149       42                    133
# 1431             7             232      82        8                     68
# 1432             5             157      60       10                     55
#
#       ...  blocks  defensive_rebounds  games_started  made_field_goals  \
# 0     ...      50                 524             67               651
# 1     ...     102                 490             58               647
# 2     ...      60                 233             60               624
# 3     ...      28                 443             57               629
# 4     ...      19                 604             73               633
# ...   ...     ...                 ...            ...               ...
# 1428  ...       2                  60             24               121
# 1429  ...      47                 172             23                72
# 1430  ...       6                  29              9                56
# 1431  ...       4                  46              6                30
# 1432  ...       2                  16              5                24
#
#       made_free_throws  made_three_point_field_goals  offensive_rebounds  \
# 0                  488                           218                  73
# 1                  591                            61                 105
# 2                  584                            52                  54
# 3                  463                           158                  48
# 4                  391                           212                 139
# ...                ...                           ...                 ...
# 1428                98                             8                  15
# 1429                18                             0                  83
# 1430                26                            11                   6
# 1431                22                             0                  31
# 1432                 3                             9                   5
#
#       personal_fouls  steals  turnovers
# 0                144      68        198
# 1                186      62        201
# 2                163     102        173
# 3                148      83        209
# 4                223      47        208
# ...              ...     ...        ...
# 1428              43      18         57
# 1429              56      26         27
# 1430              16      14         26
# 1431              24       4         11
# 1432              13       4          5
#
# [1433 rows x 22 columns]

# %% [markdown]
# ## Importing Advanced Statistics

# %%
df_advanced = pd.read_csv("../Data/merged_advanced_player_data_2010_2023.csv") 
df_advanced.drop(df_advanced.columns[df_advanced.columns.str.contains("Unnamed")], axis = 1, inplace = True) 
df_advanced["year"] = df_advanced["year"].apply(lambda x: int(x[:4])) 
df_advanced.drop("positions", axis = 1, inplace = True)
df_advanced
# Out:
#       year              name  age  assist_percentage  block_percentage  \
# 0     2012      LeBron James   27               33.6               1.7
# 1     2012    Kyrylo Fesenko   25                9.5               0.0
# 2     2012        Chris Paul   26               43.8               0.2
# 3     2012       Dwyane Wade   30               27.3               3.1
# 4     2012      Kevin Durant   23               17.5               2.2
# ...    ...               ...  ...                ...               ...
# 8025  2023     Frank Jackson   24               22.8               0.0
# 8026  2023    Jamaree Bouyea   23                0.0               0.0
# 8027  2023   Marko Simonovic   23                0.0               0.0
# 8028  2023     Deonte Burton   29                0.0               0.0
# 8029  2023  Alondes Williams   23                0.0               0.0
#
#       box_plus_minus  defensive_box_plus_minus  defensive_rebound_percentage  \
# 0               10.9                       2.7                          19.7
# 1                8.4                       3.6                          46.0
# 2                9.2                       2.4                           9.4
# 3                7.9                       1.9                          11.6
# 4                7.0                       0.8                          20.4
# ...              ...                       ...                           ...
# 8025           -22.2                      -9.8                          21.5
# 8026           -17.8                      -1.7                          17.8
# 8027           -21.7                      -5.8                           0.0
# 8028           -24.7                     -10.0                           0.0
# 8029           -26.6                      -5.3                          21.9
#
#       defensive_win_shares  free_throw_attempt_rate  ...  steal_percentage  \
# 0                      4.5                    0.429  ...               2.6
# 1                      0.1                    1.200  ...               6.2
# 2                      2.3                    0.339  ...               3.8
# 3                      2.9                    0.355  ...               2.7
# 4                      3.7                    0.386  ...               1.8
# ...                    ...                      ...  ...               ...
# 8025                   0.0                    0.000  ...               0.0
# 8026                   0.0                    0.000  ...               0.0
# 8027                   0.0                    0.000  ...               0.0
# 8028                   0.0                    0.000  ...               0.0
# 8029                   0.0                    0.000  ...               0.0
#
#                        team  three_point_attempt_rate  \
# 0                MIAMI HEAT                     0.127
# 1            INDIANA PACERS                     0.000
# 2      LOS ANGELES CLIPPERS                     0.239
# 3                MIAMI HEAT                     0.067
# 4     OKLAHOMA CITY THUNDER                     0.265
# ...                     ...                       ...
# 8025              UTAH JAZZ                     0.333
# 8026     WASHINGTON WIZARDS                     1.000
# 8027          CHICAGO BULLS                     1.000
# 8028       SACRAMENTO KINGS                     0.500
# 8029          BROOKLYN NETS                     0.000
#
#       total_rebound_percentage  true_shooting_percentage  turnover_percentage  \
# 0                         12.6                     0.605                 13.3
# 1                         29.8                     0.524                  0.0
# 2                          5.8                     0.581                 10.8
# 3                          8.7                     0.559                 11.8
# 4                         11.8                     0.610                 14.0
# ...                        ...                       ...                  ...
# 8025                      21.7                     0.000                  0.0
# 8026                       9.3                     0.000                  0.0
# 8027                       0.0                     0.000                  0.0
# 8028                       0.0                     0.000                  0.0
# 8029                      11.3                     0.000                100.0
#
#       usage_percentage value_over_replacement_player  win_shares  \
# 0                 32.0                           7.6        14.5
# 1                 20.4                           0.0         0.1
# 2                 24.3                           6.1        12.7
# 3                 31.3                           4.0         7.7
# 4                 31.3                           5.8        12.2
# ...                ...                           ...         ...
# 8025              25.1                           0.0         0.0
# 8026               7.3                           0.0         0.0
# 8027               8.8                           0.0         0.0
# 8028              14.3                           0.0         0.0
# 8029              17.8                           0.0        -0.1
#
#      win_shares_per_48_minutes
# 0                        0.298
# 1                        0.374
# 2                        0.278
# 3                        0.227
# 4                        0.230
# ...                        ...
# 8025                    -0.374
# 8026                    -0.149
# 8027                    -0.201
# 8028                    -0.349
# 8029                    -0.517
#
# [8030 rows x 28 columns]

# %%
targets = ["year", "slug", "name", "team", "age", "games_played"] 
targets = targets[::-1]
cols = list(df_advanced.columns)
for col in targets: 
    cols.insert(0, cols.pop(cols.index(col))) 
df_advanced = df_advanced.loc[:, cols]
df_advanced.rename(columns = {"year": "season"}, inplace = True)
df_advanced
# Out:
#       season       slug              name                   team  age  \
# 0       2012  jamesle01      LeBron James             MIAMI HEAT   27
# 1       2012  fesenky01    Kyrylo Fesenko         INDIANA PACERS   25
# 2       2012   paulch01        Chris Paul   LOS ANGELES CLIPPERS   26
# 3       2012   wadedw01       Dwyane Wade             MIAMI HEAT   30
# 4       2012  duranke01      Kevin Durant  OKLAHOMA CITY THUNDER   23
# ...      ...        ...               ...                    ...  ...
# 8025    2023  jacksfr01     Frank Jackson              UTAH JAZZ   24
# 8026    2023  bouyeja01    Jamaree Bouyea     WASHINGTON WIZARDS   23
# 8027    2023  simonma01   Marko Simonovic          CHICAGO BULLS   23
# 8028    2023  burtode02     Deonte Burton       SACRAMENTO KINGS   29
# 8029    2023  willial06  Alondes Williams          BROOKLYN NETS   23
#
#       games_played  assist_percentage  block_percentage  box_plus_minus  \
# 0               62               33.6               1.7            10.9
# 1                3                9.5               0.0             8.4
# 2               60               43.8               0.2             9.2
# 3               49               27.3               3.1             7.9
# 4               66               17.5               2.2             7.0
# ...            ...                ...               ...             ...
# 8025             1               22.8               0.0           -22.2
# 8026             1                0.0               0.0           -17.8
# 8027             3                0.0               0.0           -21.7
# 8028             2                0.0               0.0           -24.7
# 8029             1                0.0               0.0           -26.6
#
#       defensive_box_plus_minus  ...  player_efficiency_rating  \
# 0                          2.7  ...                      30.7
# 1                          3.6  ...                      29.8
# 2                          2.4  ...                      27.0
# 3                          1.9  ...                      26.3
# 4                          0.8  ...                      26.2
# ...                        ...  ...                       ...
# 8025                      -9.8  ...                      -6.8
# 8026                      -1.7  ...                      -7.0
# 8027                      -5.8  ...                     -10.8
# 8028                     -10.0  ...                     -12.6
# 8029                      -5.3  ...                     -20.9
#
#       steal_percentage  three_point_attempt_rate  total_rebound_percentage  \
# 0                  2.6                     0.127                      12.6
# 1                  6.2                     0.000                      29.8
# 2                  3.8                     0.239                       5.8
# 3                  2.7                     0.067                       8.7
# 4                  1.8                     0.265                      11.8
# ...                ...                       ...                       ...
# 8025               0.0                     0.333                      21.7
# 8026               0.0                     1.000                       9.3
# 8027               0.0                     1.000                       0.0
# 8028               0.0                     0.500                       0.0
# 8029               0.0                     0.000                      11.3
#
#       true_shooting_percentage  turnover_percentage  usage_percentage  \
# 0                        0.605                 13.3              32.0
# 1                        0.524                  0.0              20.4
# 2                        0.581                 10.8              24.3
# 3                        0.559                 11.8              31.3
# 4                        0.610                 14.0              31.3
# ...                        ...                  ...               ...
# 8025                     0.000                  0.0              25.1
# 8026                     0.000                  0.0               7.3
# 8027                     0.000                  0.0               8.8
# 8028                     0.000                  0.0              14.3
# 8029                     0.000                100.0              17.8
#
#       value_over_replacement_player  win_shares  win_shares_per_48_minutes
# 0                               7.6        14.5                      0.298
# 1                               0.0         0.1                      0.374
# 2                               6.1        12.7                      0.278
# 3                               4.0         7.7                      0.227
# 4                               5.8        12.2                      0.230
# ...                             ...         ...                        ...
# 8025                            0.0         0.0                     -0.374
# 8026                            0.0         0.0                     -0.149
# 8027                            0.0         0.0                     -0.201
# 8028                            0.0         0.0                     -0.349
# 8029                            0.0        -0.1                     -0.517
#
# [8030 rows x 28 columns]

# %% [markdown]
# # Clean up duplicates due to trades

# %%
id_cols = df_all.iloc[:, :5].columns 
stats_cols = df_all.iloc[:, 5:].columns 
df_group = df_all.groupby(["season", "slug", "name"]) 
df_str = df_group.agg({"team": lambda x: ", ".join(x), "age": "mean"})
df_int = df_group[stats_cols].agg("sum")
df_no_dup = df_str.merge(df_int, left_index = True, right_index = True).reset_index()
df_no_dup["age"] = df_no_dup["age"].astype("int")
df_no_dup
# Out:
#       season       slug               name                    team  age  \
# 0       2010  aldrila01  LaMarcus Aldridge  PORTLAND TRAIL BLAZERS   24
# 1       2010  allenra02          Ray Allen          BOSTON CELTICS   34
# 2       2010  anthoca01    Carmelo Anthony          DENVER NUGGETS   25
# 3       2010  arenagi01     Gilbert Arenas      WASHINGTON WIZARDS   28
# 4       2010  arizatr01       Trevor Ariza         HOUSTON ROCKETS   24
# ...      ...        ...                ...                     ...  ...
# 1372    2023  washipj01    P.J. Washington       CHARLOTTE HORNETS   24
# 1373    2023  westbru01  Russell Westbrook    LOS ANGELES CLIPPERS   34
# 1374    2023  wiggian01     Andrew Wiggins   GOLDEN STATE WARRIORS   27
# 1375    2023  willizi01    Zion Williamson    NEW ORLEANS PELICANS   22
# 1376    2023  youngtr01         Trae Young           ATLANTA HAWKS   24
#
#       games_played  minutes_played  points  assists  attempted_field_goals  \
# 0               78            2922    1393      160                   1169
# 1               80            2819    1304      210                    973
# 2               69            2634    1943      222                   1502
# 3               32            1169     722      230                    616
# 4               72            2629    1072      276                    999
# ...            ...             ...     ...      ...                    ...
# 1372            68            2235    1026      159                    884
# 1373            11             334     144       86                    127
# 1374            37            1190     633       85                    529
# 1375            29             956     754      133                    469
# 1376            64            2232    1711      642                   1255
#
#       ...  blocks  defensive_rebounds  games_started  made_field_goals  \
# 0     ...      48                 435             78               579
# 1     ...      25                 208             80               464
# 2     ...      30                 302             69               688
# 3     ...       9                 116             32               253
# 4     ...      40                 325             71               394
# ...   ...     ...                 ...            ...               ...
# 1372  ...      77                 263             68               388
# 1373  ...       3                  43             11                57
# 1374  ...      28                 125             37               250
# 1375  ...      16                 144             29               285
# 1376  ...       9                 146             64               545
#
#       made_free_throws  made_three_point_field_goals  offensive_rebounds  \
# 0                  230                             5                 192
# 1                  231                           145                  45
# 2                  508                            59                 152
# 3                  153                            63                  17
# 4                  148                           136                  78
# ...                ...                           ...                 ...
# 1372               115                           135                  67
# 1373                21                             9                  14
# 1374                44                            89                  61
# 1375               177                             7                  58
# 1376               480                           141                  52
#
#       personal_fouls  steals  turnovers
# 0                231      67        104
# 1                182      64        129
# 2                225      88        209
# 3                 95      41        117
# 4                162     126        161
# ...              ...     ...        ...
# 1372             182      61        101
# 1373              26      14         42
# 1374             107      45         48
# 1375              65      32         99
# 1376              94      72        261
#
# [1377 rows x 22 columns]

# %%
id_cols = df_advanced.iloc[:, :5].columns 
stats_cols = df_advanced.iloc[:, 5:].columns 
df_group = df_advanced.groupby(["season", "slug", "name"]) 
df_str = df_group.agg({"team": lambda x: ", ".join(x), "age": "mean"})
df_int = df_group[stats_cols].agg("sum")
df_no_dup_advanced = df_str.merge(df_int, left_index = True, right_index = True).reset_index()
df_no_dup_advanced["age"] = df_no_dup_advanced["age"].astype("int")
df_no_dup_advanced
# Out:
#       season       slug               name                    team  age  \
# 0       2010  afflaar01      Arron Afflalo          DENVER NUGGETS   24
# 1       2010  ajincal01      Alexis Ajinça       CHARLOTTE BOBCATS   21
# 2       2010  aldrila01  LaMarcus Aldridge  PORTLAND TRAIL BLAZERS   24
# 3       2010  alexajo01      Joe Alexander           CHICAGO BULLS   23
# 4       2010  allenma01        Malik Allen          DENVER NUGGETS   31
# ...      ...        ...                ...                     ...  ...
# 7036    2023  youngth01     Thaddeus Young         TORONTO RAPTORS   34
# 7037    2023  youngtr01         Trae Young           ATLANTA HAWKS   24
# 7038    2023  yurtsom01     Omer Yurtseven              MIAMI HEAT   24
# 7039    2023  zelleco01        Cody Zeller              MIAMI HEAT   30
# 7040    2023  zubaciv01        Ivica Zubac    LOS ANGELES CLIPPERS   25
#
#       games_played  assist_percentage  block_percentage  box_plus_minus  \
# 0               82                9.3               1.0            -0.4
# 1                6                0.0               2.7            -5.3
# 2               78                9.9               1.3             1.2
# 3                8                9.3               2.6            -8.3
# 4               51                5.1               0.8            -5.7
# ...            ...                ...               ...             ...
# 7036            54               13.0               0.6             0.0
# 7037            64               42.6               0.3             3.6
# 7038             5                0.0               3.0            -8.7
# 7039            10                6.7               3.1            -4.3
# 7040            66                5.2               4.0            -1.1
#
#       defensive_box_plus_minus  ...  player_efficiency_rating  \
# 0                         -0.2  ...                      10.9
# 1                          1.0  ...                       6.3
# 2                         -0.2  ...                      18.2
# 3                          0.9  ...                       2.8
# 4                         -1.0  ...                       5.9
# ...                        ...  ...                       ...
# 7036                       1.8  ...                      14.1
# 7037                      -1.8  ...                      22.5
# 7038                      -2.5  ...                       9.4
# 7039                      -0.5  ...                      13.1
# 7040                       0.2  ...                      16.3
#
#       steal_percentage  three_point_attempt_rate  total_rebound_percentage  \
# 0                  1.0                     0.426                       6.5
# 1                  1.8                     0.000                       8.0
# 2                  1.3                     0.014                      13.3
# 3                  1.8                     0.167                       9.6
# 4                  1.2                     0.052                      10.4
# ...                ...                       ...                       ...
# 7036               3.4                     0.172                      11.8
# 7037               1.5                     0.333                       4.8
# 7038               1.5                     0.125                      13.7
# 7039               0.8                     0.034                      15.7
# 7040               0.6                     0.004                      19.5
#
#       true_shooting_percentage  turnover_percentage  usage_percentage  \
# 0                        0.576                 10.5              14.0
# 1                        0.479                 16.1              19.3
# 2                        0.535                  7.4              22.9
# 3                        0.273                  0.0              11.3
# 4                        0.431                 15.3              14.0
# ...                        ...                  ...               ...
# 7036                     0.573                 16.7              13.5
# 7037                     0.573                 14.9              33.1
# 7038                     0.507                 10.1              12.8
# 7039                     0.601                 17.0              16.0
# 7040                     0.650                 16.8              14.5
#
#       value_over_replacement_player  win_shares  win_shares_per_48_minutes
# 0                               0.9         4.3                      0.092
# 1                               0.0         0.0                     -0.013
# 2                               2.3         8.8                      0.145
# 3                               0.0         0.0                      0.030
# 4                              -0.4         0.1                      0.009
# ...                             ...         ...                        ...
# 7036                            0.4         1.8                      0.107
# 7037                            3.2         5.9                      0.128
# 7038                           -0.1         0.1                      0.077
# 7039                           -0.1         0.3                      0.124
# 7040                            0.5         5.7                      0.143
#
# [7041 rows x 28 columns]

# %% [markdown]
# # Per game Data

# %%
df_id = df_no_dup.iloc[:, :7]
df_per_game = df_no_dup.iloc[:, 7:].div(df_no_dup["games_played"], axis = 0) 
df_per_game = df_id.merge(df_per_game, left_index = True, right_index = True)
df_per_game
# Out:
#       season       slug               name                    team  age  \
# 0       2010  aldrila01  LaMarcus Aldridge  PORTLAND TRAIL BLAZERS   24
# 1       2010  allenra02          Ray Allen          BOSTON CELTICS   34
# 2       2010  anthoca01    Carmelo Anthony          DENVER NUGGETS   25
# 3       2010  arenagi01     Gilbert Arenas      WASHINGTON WIZARDS   28
# 4       2010  arizatr01       Trevor Ariza         HOUSTON ROCKETS   24
# ...      ...        ...                ...                     ...  ...
# 1372    2023  washipj01    P.J. Washington       CHARLOTTE HORNETS   24
# 1373    2023  westbru01  Russell Westbrook    LOS ANGELES CLIPPERS   34
# 1374    2023  wiggian01     Andrew Wiggins   GOLDEN STATE WARRIORS   27
# 1375    2023  willizi01    Zion Williamson    NEW ORLEANS PELICANS   22
# 1376    2023  youngtr01         Trae Young           ATLANTA HAWKS   24
#
#       games_played  minutes_played     points    assists  \
# 0               78            2922  17.858974   2.051282
# 1               80            2819  16.300000   2.625000
# 2               69            2634  28.159420   3.217391
# 3               32            1169  22.562500   7.187500
# 4               72            2629  14.888889   3.833333
# ...            ...             ...        ...        ...
# 1372            68            2235  15.088235   2.338235
# 1373            11             334  13.090909   7.818182
# 1374            37            1190  17.108108   2.297297
# 1375            29             956  26.000000   4.586207
# 1376            64            2232  26.734375  10.031250
#
#       attempted_field_goals  ...    blocks  defensive_rebounds  games_started  \
# 0                 14.987179  ...  0.615385            5.576923       1.000000
# 1                 12.162500  ...  0.312500            2.600000       1.000000
# 2                 21.768116  ...  0.434783            4.376812       1.000000
# 3                 19.250000  ...  0.281250            3.625000       1.000000
# 4                 13.875000  ...  0.555556            4.513889       0.986111
# ...                     ...  ...       ...                 ...            ...
# 1372              13.000000  ...  1.132353            3.867647       1.000000
# 1373              11.545455  ...  0.272727            3.909091       1.000000
# 1374              14.297297  ...  0.756757            3.378378       1.000000
# 1375              16.172414  ...  0.551724            4.965517       1.000000
# 1376              19.609375  ...  0.140625            2.281250       1.000000
#
#       made_field_goals  made_free_throws  made_three_point_field_goals  \
# 0             7.423077          2.948718                      0.064103
# 1             5.800000          2.887500                      1.812500
# 2             9.971014          7.362319                      0.855072
# 3             7.906250          4.781250                      1.968750
# 4             5.472222          2.055556                      1.888889
# ...                ...               ...                           ...
# 1372          5.705882          1.691176                      1.985294
# 1373          5.181818          1.909091                      0.818182
# 1374          6.756757          1.189189                      2.405405
# 1375          9.827586          6.103448                      0.241379
# 1376          8.515625          7.500000                      2.203125
#
#       offensive_rebounds  personal_fouls    steals  turnovers
# 0               2.461538        2.961538  0.858974   1.333333
# 1               0.562500        2.275000  0.800000   1.612500
# 2               2.202899        3.260870  1.275362   3.028986
# 3               0.531250        2.968750  1.281250   3.656250
# 4               1.083333        2.250000  1.750000   2.236111
# ...                  ...             ...       ...        ...
# 1372            0.985294        2.676471  0.897059   1.485294
# 1373            1.272727        2.363636  1.272727   3.818182
# 1374            1.648649        2.891892  1.216216   1.297297
# 1375            2.000000        2.241379  1.103448   3.413793
# 1376            0.812500        1.468750  1.125000   4.078125
#
# [1377 rows x 22 columns]

# %% [markdown]
# # Create efficiency stats

# %%
df_per_game.columns
# Out:
# Index(['season', 'slug', 'name', 'team', 'age', 'games_played',
#        'minutes_played', 'points', 'assists', 'attempted_field_goals',
#        'attempted_free_throws', 'attempted_three_point_field_goals', 'blocks',
#        'defensive_rebounds', 'games_started', 'made_field_goals',
#        'made_free_throws', 'made_three_point_field_goals',
#        'offensive_rebounds', 'personal_fouls', 'steals', 'turnovers'],
#       dtype='object')

# %%
df_advanced.columns
# Out:
# Index(['season', 'slug', 'name', 'team', 'age', '%games_played',
#        'assist_percentage', 'block_percentage', 'box_plus_minus',
#        'defensive_box_plus_minus', 'defensive_rebound_percentage',
#        'defensive_win_shares', 'free_throw_attempt_rate', 'is_combined_totals',
#        'minutes_played', 'offensive_box_plus_minus',
#        'offensive_rebound_percentage', 'offensive_win_shares',
#        'player_efficiency_rating', 'steal_percentage',
#        'three_point_attempt_rate', 'total_rebound_percentage',
#        'true_shooting_percentage', 'turnover_percentage', 'usage_percentage',
#        'value_over_replacement_player', 'win_shares',
#        'win_shares_per_48_minutes'],
#       dtype='object')

# %% [markdown]
# ## Create %games_played

# %%
df_num_games_2020 = pd.read_csv("../Data/num_games_2020.csv") 
df_num_games_2020
# Out:
#    Unnamed: 0              Unnamed: 1 Unnamed: 2  Place Place.1 Conference  \
# 0          Rk                    Team    Overall   Home    Road          E
# 1           1         Milwaukee Bucks      56-17   30-5   26-12       37-7
# 2           2         Toronto Raptors      53-19  26-10    27-9      34-11
# 3           3      Los Angeles Lakers      52-19  25-10    27-9       16-9
# 4           4    Los Angeles Clippers      49-23   27-9   22-14       17-7
# 5           5          Boston Celtics      48-24  26-10   22-14      30-13
# 6           6          Denver Nuggets      46-27  26-11   20-16      17-11
# 7           7          Indiana Pacers      45-28  25-11   20-17      28-19
# 8           8         Houston Rockets      44-28  24-12   20-16       16-9
# 9           9              Miami Heat      44-29   29-7   15-22      30-13
# 10         10   Oklahoma City Thunder      44-28  23-14   21-14       17-9
# 11         11               Utah Jazz      44-28  23-12   21-16       20-7
# 12         12        Dallas Mavericks      43-32  20-18   23-14      16-12
# 13         13      Philadelphia 76ers      43-30   31-4   12-26      28-18
# 14         14           Brooklyn Nets      35-37  20-16   15-21      23-23
# 15         15  Portland Trail Blazers      35-39  21-15   14-24      15-12
# 16         16       Memphis Grizzlies      34-39  20-17   14-22      14-13
# 17         17            Phoenix Suns      34-39  17-22   17-17      15-12
# 18         18           Orlando Magic      33-40  18-17   15-23      20-23
# 19         19       San Antonio Spurs      32-39  19-15   13-24      12-16
# 20         20        Sacramento Kings      31-41  16-19   15-22       8-18
# 21         21    New Orleans Pelicans      30-42  15-21   15-21      12-12
# 22         22      Washington Wizards      25-47  16-20    9-27      18-27
# 23         23       Charlotte Hornets      23-42  10-21   13-21      16-24
# 24         24           Chicago Bulls      22-43  14-20    8-23      15-28
# 25         25         New York Knicks      21-45  11-22   10-23      15-28
# 26         26           Atlanta Hawks      20-47  14-20    6-27      11-32
# 27         27         Detroit Pistons      20-46  11-22    9-24      12-31
# 28         28     Cleveland Cavaliers      19-46  11-25    8-21      12-32
# 29         29  Minnesota Timberwolves      19-45   8-24   11-21      10-15
# 30         30   Golden State Warriors      15-50   8-26    7-24       6-16
#
#    Conference.1 Division Division.1 Division.2  ... Margin Margin.1 Month  \
# 0             W        A          C         SE  ...     ≤3      ≥10   Oct
# 1         19-10     10-4       13-1       14-2  ...    3-2     38-8   2-2
# 2          19-8      9-5       13-3       12-3  ...    6-4    23-10   4-1
# 3         36-10      5-5        4-3        7-1  ...    7-3    25-11   3-1
# 4         32-16      5-3        4-3        8-1  ...    8-3     32-8   4-2
# 5         18-11      9-6        9-4       12-3  ...    6-5     29-7   3-1
# 6         29-16      6-4        4-4        7-3  ...    9-5    16-13   3-2
# 7          17-9      9-7        8-7       11-5  ...    5-7    20-12   1-3
# 8         28-19      6-3        4-3        6-3  ...    4-5    22-14   3-1
# 9         14-16      9-6       11-3       10-4  ...    6-4    23-11   4-1
# 10        27-19      5-3        6-4        6-2  ...    8-6    18-10   1-4
# 11        24-21      6-4        6-2        8-1  ...    7-5    18-11   4-1
# 12        27-20      4-5        7-2        5-5  ...   2-11     23-9   3-1
# 13        15-12     11-5       10-6        7-7  ...    6-5    19-15   4-0
# 14        12-14     6-10        8-4        9-9  ...    7-7    17-19   1-3
# 15        20-27      4-6        4-4        7-2  ...    9-3    17-18   3-2
# 16        20-26      3-4        4-6        7-3  ...    3-4    18-21   1-3
# 17        19-27      6-4        3-4        6-4  ...    4-8    15-18   3-2
# 18        13-17     6-10        5-8        9-5  ...    5-5    18-20   2-2
# 19        20-23      5-5        2-6        5-5  ...   10-7    10-12   3-1
# 20        23-23      2-8        2-5        4-5  ...    6-8    12-18   0-5
# 21        18-30      2-6        7-3        3-3  ...    2-6    18-15   1-4
# 22         7-20      8-7       5-11        5-9  ...    1-4    12-25   1-3
# 23         7-18      5-9        9-8        2-7  ...    9-8     5-25   2-3
# 24         7-15     1-12        7-9        7-7  ...    6-6     7-19   1-4
# 25         6-17     2-11        8-8        5-9  ...    7-6     8-21   1-4
# 26         9-15     3-13       2-12        6-7  ...    1-5     8-29   2-3
# 27         8-15     3-11       5-10       4-10  ...    4-6     9-26   2-3
# 28         7-14     2-14       4-10        6-8  ...    5-5     6-28   2-2
# 29         9-30      2-4        3-6        5-5  ...    3-4    10-21   3-1
# 30         9-34      1-6        3-3        2-7  ...    1-3     8-30   1-3
#
#    Month.1 Month.2 Month.3 Month.4 Month.5 Month.6 Month.7
# 0      Nov     Dec     Jan     Feb     Mar     Jul     Aug
# 1     15-1    13-2    11-2    10-1     2-4     1-0     2-5
# 2     10-3     9-7    12-3     7-3     4-1     NaN     7-1
# 3     14-1     9-5    10-4     9-2     4-1     1-0     2-5
# 4     10-4    10-5     9-4     7-4     4-1     0-1     5-2
# 5     10-4    10-3     9-7     9-3     2-3     0-1     5-2
# 6     10-2    10-6    11-5     6-4     3-3     NaN     3-5
# 7     11-4    10-5     9-5     5-7     3-2     NaN     6-2
# 8     10-5    10-5     7-7     9-2     1-4     1-0     3-4
# 9      9-4    11-4     8-6     6-7     3-2     NaN     3-5
# 10     6-7    11-4    12-5     7-3     3-1     NaN     4-4
# 11     8-6     9-5    11-4     5-6     4-1     1-0     2-5
# 12     9-5     9-6     8-7     7-5     4-3     0-1     3-4
# 13    10-6     9-7     8-5     6-5     2-3     NaN     4-4
# 14     9-6     6-7    5-10     5-7     4-1     0-1     5-2
# 15    5-10     6-8     8-7     4-8     3-2     1-0     5-2
# 16    4-10     8-8    11-4     5-6     3-2     0-1     2-5
# 17     5-8    5-10     7-8     4-9     2-2     1-0     7-0
# 18     5-9     7-8     7-8     6-6     3-2     1-0     2-5
# 19    4-12     7-5     7-8     4-7     2-3     1-0     4-3
# 20     8-5    4-12     6-8     7-4     3-2     0-1     3-4
# 21     5-9    5-10     9-6     6-4     2-3     0-1     2-5
# 22     5-8    4-11     6-9     5-6     3-3     0-1     1-6
# 23    6-10    5-10     3-9     5-6     2-4     NaN     NaN
# 24    5-10     7-7    6-11     1-8     2-3     NaN     NaN
# 25    3-11     5-9    4-12     5-6     3-3     NaN     NaN
# 26    2-13    3-11     6-9     6-7     1-4     NaN     NaN
# 27    4-10     6-9    5-11     3-8     0-5     NaN     NaN
# 28    3-12     5-9    3-13     4-7     2-3     NaN     NaN
# 29     7-7    2-12    3-12     2-9     2-4     NaN     NaN
# 30    3-13    5-10    1-13     3-8     2-3     NaN     NaN
#
# [31 rows x 25 columns]

# %%
df_num_games_2020 = df_num_games_2020.iloc[1:, 1:3] 
df_num_games_2020.rename(columns = {"Unnamed: 1": "team", "Unnamed: 2": "record"}, inplace = True) 
df_num_games_2020["total_games"] = df_num_games_2020["record"].apply(lambda x: int(x.split("-")[0]) + int(x.split("-")[1])) 
df_num_games_2020.drop("record", axis = 1, inplace = True) 
df_num_games_2020["team"] = df_num_games_2020["team"].apply(lambda x: x.upper())
df_num_games_2020
# Out:
#                       team  total_games
# 1          MILWAUKEE BUCKS           73
# 2          TORONTO RAPTORS           72
# 3       LOS ANGELES LAKERS           71
# 4     LOS ANGELES CLIPPERS           72
# 5           BOSTON CELTICS           72
# 6           DENVER NUGGETS           73
# 7           INDIANA PACERS           73
# 8          HOUSTON ROCKETS           72
# 9               MIAMI HEAT           73
# 10   OKLAHOMA CITY THUNDER           72
# 11               UTAH JAZZ           72
# 12        DALLAS MAVERICKS           75
# 13      PHILADELPHIA 76ERS           73
# 14           BROOKLYN NETS           72
# 15  PORTLAND TRAIL BLAZERS           74
# 16       MEMPHIS GRIZZLIES           73
# 17            PHOENIX SUNS           73
# 18           ORLANDO MAGIC           73
# 19       SAN ANTONIO SPURS           71
# 20        SACRAMENTO KINGS           72
# 21    NEW ORLEANS PELICANS           72
# 22      WASHINGTON WIZARDS           72
# 23       CHARLOTTE HORNETS           65
# 24           CHICAGO BULLS           65
# 25         NEW YORK KNICKS           66
# 26           ATLANTA HAWKS           67
# 27         DETROIT PISTONS           66
# 28     CLEVELAND CAVALIERS           65
# 29  MINNESOTA TIMBERWOLVES           64
# 30   GOLDEN STATE WARRIORS           65

# %%
def fill_total_games(df): 
    if df["season"] == 2021: 
        return 72 
    elif df["season"] == 2020: 
        try: 
            return df_num_games_2020[df_num_games_2020["team"] == df["team"]]["total_games"].values[0] 
        except IndexError: #Handle traded players by returning the average num_games played by all teams
            return int(df_num_games_2020["total_games"].mean())
    else: 
        return 82

# %%
df_per_game["total_games"] = df_per_game.apply(lambda x: fill_total_games(x), axis = 1)
df_per_game["games_played"] = df_per_game["games_played"]/df_per_game["total_games"] 
df_per_game = df_per_game.rename(columns = {"games_played": "%games_played"}).drop("total_games", axis = 1)
df_per_game
# Out:
#       season       slug               name                    team  age  \
# 0       2010  aldrila01  LaMarcus Aldridge  PORTLAND TRAIL BLAZERS   24
# 1       2010  allenra02          Ray Allen          BOSTON CELTICS   34
# 2       2010  anthoca01    Carmelo Anthony          DENVER NUGGETS   25
# 3       2010  arenagi01     Gilbert Arenas      WASHINGTON WIZARDS   28
# 4       2010  arizatr01       Trevor Ariza         HOUSTON ROCKETS   24
# ...      ...        ...                ...                     ...  ...
# 1372    2023  washipj01    P.J. Washington       CHARLOTTE HORNETS   24
# 1373    2023  westbru01  Russell Westbrook    LOS ANGELES CLIPPERS   34
# 1374    2023  wiggian01     Andrew Wiggins   GOLDEN STATE WARRIORS   27
# 1375    2023  willizi01    Zion Williamson    NEW ORLEANS PELICANS   22
# 1376    2023  youngtr01         Trae Young           ATLANTA HAWKS   24
#
#       %games_played  minutes_played     points    assists  \
# 0          0.951220            2922  17.858974   2.051282
# 1          0.975610            2819  16.300000   2.625000
# 2          0.841463            2634  28.159420   3.217391
# 3          0.390244            1169  22.562500   7.187500
# 4          0.878049            2629  14.888889   3.833333
# ...             ...             ...        ...        ...
# 1372       0.829268            2235  15.088235   2.338235
# 1373       0.134146             334  13.090909   7.818182
# 1374       0.451220            1190  17.108108   2.297297
# 1375       0.353659             956  26.000000   4.586207
# 1376       0.780488            2232  26.734375  10.031250
#
#       attempted_field_goals  ...    blocks  defensive_rebounds  games_started  \
# 0                 14.987179  ...  0.615385            5.576923       1.000000
# 1                 12.162500  ...  0.312500            2.600000       1.000000
# 2                 21.768116  ...  0.434783            4.376812       1.000000
# 3                 19.250000  ...  0.281250            3.625000       1.000000
# 4                 13.875000  ...  0.555556            4.513889       0.986111
# ...                     ...  ...       ...                 ...            ...
# 1372              13.000000  ...  1.132353            3.867647       1.000000
# 1373              11.545455  ...  0.272727            3.909091       1.000000
# 1374              14.297297  ...  0.756757            3.378378       1.000000
# 1375              16.172414  ...  0.551724            4.965517       1.000000
# 1376              19.609375  ...  0.140625            2.281250       1.000000
#
#       made_field_goals  made_free_throws  made_three_point_field_goals  \
# 0             7.423077          2.948718                      0.064103
# 1             5.800000          2.887500                      1.812500
# 2             9.971014          7.362319                      0.855072
# 3             7.906250          4.781250                      1.968750
# 4             5.472222          2.055556                      1.888889
# ...                ...               ...                           ...
# 1372          5.705882          1.691176                      1.985294
# 1373          5.181818          1.909091                      0.818182
# 1374          6.756757          1.189189                      2.405405
# 1375          9.827586          6.103448                      0.241379
# 1376          8.515625          7.500000                      2.203125
#
#       offensive_rebounds  personal_fouls    steals  turnovers
# 0               2.461538        2.961538  0.858974   1.333333
# 1               0.562500        2.275000  0.800000   1.612500
# 2               2.202899        3.260870  1.275362   3.028986
# 3               0.531250        2.968750  1.281250   3.656250
# 4               1.083333        2.250000  1.750000   2.236111
# ...                  ...             ...       ...        ...
# 1372            0.985294        2.676471  0.897059   1.485294
# 1373            1.272727        2.363636  1.272727   3.818182
# 1374            1.648649        2.891892  1.216216   1.297297
# 1375            2.000000        2.241379  1.103448   3.413793
# 1376            0.812500        1.468750  1.125000   4.078125
#
# [1377 rows x 22 columns]

# %%
df_advanced["total_games"] = df_advanced.apply(lambda x: fill_total_games(x), axis = 1)
df_advanced["games_played"] = df_advanced["games_played"]/df_advanced["total_games"] 
df_advanced = df_advanced.rename(columns = {"games_played": "%games_played"}).drop("total_games", axis = 1)
df_advanced
# Out:
#       season       slug              name                   team  age  \
# 0       2012  jamesle01      LeBron James             MIAMI HEAT   27
# 1       2012  fesenky01    Kyrylo Fesenko         INDIANA PACERS   25
# 2       2012   paulch01        Chris Paul   LOS ANGELES CLIPPERS   26
# 3       2012   wadedw01       Dwyane Wade             MIAMI HEAT   30
# 4       2012  duranke01      Kevin Durant  OKLAHOMA CITY THUNDER   23
# ...      ...        ...               ...                    ...  ...
# 8025    2023  jacksfr01     Frank Jackson              UTAH JAZZ   24
# 8026    2023  bouyeja01    Jamaree Bouyea     WASHINGTON WIZARDS   23
# 8027    2023  simonma01   Marko Simonovic          CHICAGO BULLS   23
# 8028    2023  burtode02     Deonte Burton       SACRAMENTO KINGS   29
# 8029    2023  willial06  Alondes Williams          BROOKLYN NETS   23
#
#       %games_played  assist_percentage  block_percentage  box_plus_minus  \
# 0          0.756098               33.6               1.7            10.9
# 1          0.036585                9.5               0.0             8.4
# 2          0.731707               43.8               0.2             9.2
# 3          0.597561               27.3               3.1             7.9
# 4          0.804878               17.5               2.2             7.0
# ...             ...                ...               ...             ...
# 8025       0.012195               22.8               0.0           -22.2
# 8026       0.012195                0.0               0.0           -17.8
# 8027       0.036585                0.0               0.0           -21.7
# 8028       0.024390                0.0               0.0           -24.7
# 8029       0.012195                0.0               0.0           -26.6
#
#       defensive_box_plus_minus  ...  player_efficiency_rating  \
# 0                          2.7  ...                      30.7
# 1                          3.6  ...                      29.8
# 2                          2.4  ...                      27.0
# 3                          1.9  ...                      26.3
# 4                          0.8  ...                      26.2
# ...                        ...  ...                       ...
# 8025                      -9.8  ...                      -6.8
# 8026                      -1.7  ...                      -7.0
# 8027                      -5.8  ...                     -10.8
# 8028                     -10.0  ...                     -12.6
# 8029                      -5.3  ...                     -20.9
#
#       steal_percentage  three_point_attempt_rate  total_rebound_percentage  \
# 0                  2.6                     0.127                      12.6
# 1                  6.2                     0.000                      29.8
# 2                  3.8                     0.239                       5.8
# 3                  2.7                     0.067                       8.7
# 4                  1.8                     0.265                      11.8
# ...                ...                       ...                       ...
# 8025               0.0                     0.333                      21.7
# 8026               0.0                     1.000                       9.3
# 8027               0.0                     1.000                       0.0
# 8028               0.0                     0.500                       0.0
# 8029               0.0                     0.000                      11.3
#
#       true_shooting_percentage  turnover_percentage  usage_percentage  \
# 0                        0.605                 13.3              32.0
# 1                        0.524                  0.0              20.4
# 2                        0.581                 10.8              24.3
# 3                        0.559                 11.8              31.3
# 4                        0.610                 14.0              31.3
# ...                        ...                  ...               ...
# 8025                     0.000                  0.0              25.1
# 8026                     0.000                  0.0               7.3
# 8027                     0.000                  0.0               8.8
# 8028                     0.000                  0.0              14.3
# 8029                     0.000                100.0              17.8
#
#       value_over_replacement_player  win_shares  win_shares_per_48_minutes
# 0                               7.6        14.5                      0.298
# 1                               0.0         0.1                      0.374
# 2                               6.1        12.7                      0.278
# 3                               4.0         7.7                      0.227
# 4                               5.8        12.2                      0.230
# ...                             ...         ...                        ...
# 8025                            0.0         0.0                     -0.374
# 8026                            0.0         0.0                     -0.149
# 8027                            0.0         0.0                     -0.201
# 8028                            0.0         0.0                     -0.349
# 8029                            0.0        -0.1                     -0.517
#
# [8030 rows x 28 columns]

# %% [markdown]
# ## Create field_goal%, free_throw%, and 3pt%

# %% [markdown]
# # Splitting df into 2023 and the rest (2010-22)

# %%
df_2023 = df_per_game[df_per_game["season"] == 2023] 
df_box_score = df_per_game[df_per_game["season"] != 2023]

# %%
df_2023
# Out:
#       season       slug                   name                   team  age  \
# 1266    2023  adebaba01            Bam Adebayo             MIAMI HEAT   25
# 1267    2023  allenja01          Jarrett Allen    CLEVELAND CAVALIERS   24
# 1268    2023  antetgi01  Giannis Antetokounmpo        MILWAUKEE BUCKS   28
# 1269    2023  anunoog01             OG Anunoby        TORONTO RAPTORS   25
# 1270    2023  aytonde01          Deandre Ayton           PHOENIX SUNS   24
# ...      ...        ...                    ...                    ...  ...
# 1372    2023  washipj01        P.J. Washington      CHARLOTTE HORNETS   24
# 1373    2023  westbru01      Russell Westbrook   LOS ANGELES CLIPPERS   34
# 1374    2023  wiggian01         Andrew Wiggins  GOLDEN STATE WARRIORS   27
# 1375    2023  willizi01        Zion Williamson   NEW ORLEANS PELICANS   22
# 1376    2023  youngtr01             Trae Young          ATLANTA HAWKS   24
#
#       %games_played  minutes_played     points    assists  \
# 1266       0.829268            2389  21.058824   3.279412
# 1267       0.756098            2048  14.354839   1.677419
# 1268       0.682927            1820  31.250000   5.571429
# 1269       0.707317            2072  16.775862   1.896552
# 1270       0.743902            1857  18.311475   1.819672
# ...             ...             ...        ...        ...
# 1372       0.829268            2235  15.088235   2.338235
# 1373       0.134146             334  13.090909   7.818182
# 1374       0.451220            1190  17.108108   2.297297
# 1375       0.353659             956  26.000000   4.586207
# 1376       0.780488            2232  26.734375  10.031250
#
#       attempted_field_goals  ...    blocks  defensive_rebounds  games_started  \
# 1266              15.250000  ...  0.867647            6.926471            1.0
# 1267               9.225806  ...  1.209677            6.693548            1.0
# 1268              20.392857  ...  0.803571            9.607143            1.0
# 1269              13.103448  ...  0.724138            3.655172            1.0
# 1270              13.557377  ...  0.770492            7.508197            1.0
# ...                     ...  ...       ...                 ...            ...
# 1372              13.000000  ...  1.132353            3.867647            1.0
# 1373              11.545455  ...  0.272727            3.909091            1.0
# 1374              14.297297  ...  0.756757            3.378378            1.0
# 1375              16.172414  ...  0.551724            4.965517            1.0
# 1376              19.609375  ...  0.140625            2.281250            1.0
#
#       made_field_goals  made_free_throws  made_three_point_field_goals  \
# 1266          8.279412          4.485294                      0.014706
# 1267          5.983871          2.370968                      0.016129
# 1268         11.125000          8.196429                      0.803571
# 1269          6.224138          2.293103                      2.034483
# 1270          7.983607          2.229508                      0.114754
# ...                ...               ...                           ...
# 1372          5.705882          1.691176                      1.985294
# 1373          5.181818          1.909091                      0.818182
# 1374          6.756757          1.189189                      2.405405
# 1375          9.827586          6.103448                      0.241379
# 1376          8.515625          7.500000                      2.203125
#
#       offensive_rebounds  personal_fouls    steals  turnovers
# 1266            2.426471        2.867647  1.191176   2.588235
# 1267            3.112903        2.241935  0.822581   1.403226
# 1268            2.250000        3.196429  0.732143   3.910714
# 1269            1.413793        3.034483  1.965517   2.155172
# 1270            2.639344        2.836066  0.557377   1.819672
# ...                  ...             ...       ...        ...
# 1372            0.985294        2.676471  0.897059   1.485294
# 1373            1.272727        2.363636  1.272727   3.818182
# 1374            1.648649        2.891892  1.216216   1.297297
# 1375            2.000000        2.241379  1.103448   3.413793
# 1376            0.812500        1.468750  1.125000   4.078125
#
# [111 rows x 22 columns]

# %%
df_box_score
# Out:
#       season       slug               name                    team  age  \
# 0       2010  aldrila01  LaMarcus Aldridge  PORTLAND TRAIL BLAZERS   24
# 1       2010  allenra02          Ray Allen          BOSTON CELTICS   34
# 2       2010  anthoca01    Carmelo Anthony          DENVER NUGGETS   25
# 3       2010  arenagi01     Gilbert Arenas      WASHINGTON WIZARDS   28
# 4       2010  arizatr01       Trevor Ariza         HOUSTON ROCKETS   24
# ...      ...        ...                ...                     ...  ...
# 1261    2022  westbru01  Russell Westbrook      LOS ANGELES LAKERS   33
# 1262    2022  whitede01      Derrick White       SAN ANTONIO SPURS   27
# 1263    2022  wiggian01     Andrew Wiggins   GOLDEN STATE WARRIORS   26
# 1264    2022   woodch01     Christian Wood         HOUSTON ROCKETS   26
# 1265    2022  youngtr01         Trae Young           ATLANTA HAWKS   23
#
#       %games_played  minutes_played     points   assists  \
# 0          0.951220            2922  17.858974  2.051282
# 1          0.975610            2819  16.300000  2.625000
# 2          0.841463            2634  28.159420  3.217391
# 3          0.390244            1169  22.562500  7.187500
# 4          0.878049            2629  14.888889  3.833333
# ...             ...             ...        ...       ...
# 1261       0.951220            2678  18.474359  7.051282
# 1262       0.597561            1486  14.408163  5.591837
# 1263       0.890244            2329  17.205479  2.205479
# 1264       0.829268            2094  17.911765  2.279412
# 1265       0.926829            2652  28.355263  9.697368
#
#       attempted_field_goals  ...    blocks  defensive_rebounds  games_started  \
# 0                 14.987179  ...  0.615385            5.576923       1.000000
# 1                 12.162500  ...  0.312500            2.600000       1.000000
# 2                 21.768116  ...  0.434783            4.376812       1.000000
# 3                 19.250000  ...  0.281250            3.625000       1.000000
# 4                 13.875000  ...  0.555556            4.513889       0.986111
# ...                     ...  ...       ...                 ...            ...
# 1261              15.807692  ...  0.256410            6.025641       1.000000
# 1262              11.632653  ...  0.857143            3.020408       0.979592
# 1263              13.958904  ...  0.698630            3.287671       1.000000
# 1264              12.911765  ...  0.955882            8.470588       0.985294
# 1265              20.315789  ...  0.092105            3.078947       1.000000
#
#       made_field_goals  made_free_throws  made_three_point_field_goals  \
# 0             7.423077          2.948718                      0.064103
# 1             5.800000          2.887500                      1.812500
# 2             9.971014          7.362319                      0.855072
# 3             7.906250          4.781250                      1.968750
# 4             5.472222          2.055556                      1.888889
# ...                ...               ...                           ...
# 1261          7.025641          3.410256                      1.012821
# 1262          4.959184          2.836735                      1.653061
# 1263          6.506849          2.041096                      2.150685
# 1264          6.470588          3.044118                      1.926471
# 1265          9.355263          6.578947                      3.065789
#
#       offensive_rebounds  personal_fouls    steals  turnovers
# 0               2.461538        2.961538  0.858974   1.333333
# 1               0.562500        2.275000  0.800000   1.612500
# 2               2.202899        3.260870  1.275362   3.028986
# 3               0.531250        2.968750  1.281250   3.656250
# 4               1.083333        2.250000  1.750000   2.236111
# ...                  ...             ...       ...        ...
# 1261            1.410256        3.012821  0.961538   3.782051
# 1262            0.510204        2.367347  1.000000   1.775510
# 1263            1.164384        2.164384  1.041096   1.520548
# 1264            1.617647        2.514706  0.794118   1.852941
# 1265            0.657895        1.684211  0.947368   3.986842
#
# [1266 rows x 22 columns]
