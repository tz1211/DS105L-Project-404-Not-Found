# %%
import requests

import pandas as pd

from bs4 import BeautifulSoup

from datetime import datetime

# %%
news_600_author = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_author/cleaned_authors_updated/news_600_author_cl.csv')
news_1200_author = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_author/cleaned_authors_updated/news_1200_author_cl.csv')
news_1600_author = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_author/cleaned_authors_updated/news_1600_author_cl.csv')

# %%
news_600_author_1 = news_600_author.copy()
news_1200_author_1 = news_1200_author.copy()
news_1600_author_1 = news_1600_author.copy()

# %%
from tqdm import tqdm
import requests
from bs4 import BeautifulSoup

def add_credit(dataframe_author):
    author_list = list(dataframe_author["author"])
    credit_article = ["None"] * len(author_list)
    credit_followers = ["None"] * len(author_list)
    credit_tweets = ["None"] * len(author_list)
    for i, names in enumerate(tqdm(author_list)):
        if names == "NaN":
            continue
        elif "|" in str(names):
            try:
                name_1 = names.split("|")[0].strip()
                player_search = str(name_1).replace(" ", "-")
                url = "https://muckrack.com/" + player_search
                response = requests.get(url)
                soup = BeautifulSoup(response.text, 'html.parser')
                html = soup.find_all('a', attrs={'class':"profile-edit-btn"})
                if len(html) == 0:
                    num_articles = "None"
                    credit_article[i] = num_articles
                else:
                    for line in html:
                        if "See all" in line.text:
                            span_elem = line.find('span', class_="d-none d-lg-inline")
                            if span_elem is not None:
                                text_content = span_elem.text.strip()
                                num_articles = text_content.split()[0].replace(',', '')
                                credit_article[i] = num_articles
                                break

                           
                    if credit_followers[i] == "None":
                        credit_followers[i] = "None"
                        
                    tweet = soup.find('p', attrs={'class':"fs-6 mt-0 mb-6"})
                    followers = tweet.find('strong').text.replace(',', '')
                    tweets = tweet.find_all('strong')[1].text.replace(',', '')
                    if len(followers) != 0:
                        credit_followers[i] = followers
                    if len(followers) == 0:
                        followers = "0" 
                        credit_followers[i] = followers
                    if len(tweets) != 0:
                        credit_tweets[i] = tweets
                    if len(tweets) == 0:
                        tweets = "0"
                        credit_tweets[i] = tweets
            except Exception as e:
                if credit_followers[i] == "None":
                    credit_followers[i] = "None"
                if credit_tweets[i] == "None":
                    credit_tweets[i] = "None"
        elif "NBA" in str(names) or "Press" in str(names) or "Official" in str(names) or "media" in str(names):
            credit_article[i] = "Default"
            credit_followers[i] = "Default"
            credit_tweets[i] = "Default"
        else:
            try:
                player_search = str(names).replace(" ", "-")
                url = "https://muckrack.com/" + player_search
                response = requests.get(url)
                soup = BeautifulSoup(response.text, 'html.parser')
                html = soup.find_all('a', attrs={'class':"profile-edit-btn"})
                if len(html) == 0:
                    num_articles = "None"
                    credit_article[i] = num_articles
                else:
                    if "See all" in line.text:
                            span_elem = line.find('span', class_="d-none d-lg-inline")
                            if span_elem is not None:
                                text_content = span_elem.text.strip()
                                num_articles = text_content.split()[0].replace(',', '')
                                credit_article[i] = num_articles
                                break
                    if credit_followers[i] == "None":
                        credit_followers[i] = "None"
                        
                    tweet = soup.find('p', attrs={'class':"fs-6 mt-0 mb-6"})
                    followers = tweet.find('strong').text.replace(',', '')
                    tweets = tweet.find_all('strong')[1].text.replace(',', '')
                    if len(followers) != 0:
                        credit_followers[i] = followers
                    if len(followers) == 0:
                        followers = "0" 
                        credit_followers[i] = followers
                    if len(tweets) != 0:
                        credit_tweets[i] = tweets
                    if len(tweets) == 0:
                        tweets = "0"
                        credit_tweets[i] = tweets
            except Exception as e:
                if credit_followers[i] == "None":
                    credit_followers[i] = "None"
                if credit_tweets[i] == "None":
                    credit_tweets[i] = "None"
    dataframe_author["credit_article"] = credit_article
    dataframe_author["credit_followers"] = credit_followers
    dataframe_author["credit_tweets"] = credit_tweets
    return dataframe_author

# %%
news_600_author_cedit_1 = add_credit(news_600_author_1)
# Out:
# 100%|██████████| 6000/6000 [06:24<00:00, 15.60it/s]

# %%
news_600_author_cedit_1.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/author_credit_nba/news_600_author_credit_a.csv', index=False)

# %%
news_1200_author_cedit_1 = add_credit(news_1200_author_1)
# Out:
# 100%|██████████| 6000/6000 [00:57<00:00, 104.76it/s]

# %%
news_1200_author_cedit_1.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/author_credit_nba/news_1200_author_credit_a.csv', index=False)

# %%
news_1200_author_cedit_1
# Out:
#       Unnamed: 0                                              title  \
# 0              0  Warriors’ Stephen Curry To Begin Practicing Ne...
# 1              1  Pelicans’ Anthony Davis (Hip Strain) Out vs. W...
# 2              2       Rockets To Rest Chris Paul Against Cavaliers
# 3              3  Warriors Looking To Stay On Track As They Host...
# 4              4                  Bucks End Homestand Against Spurs
# ...          ...                                                ...
# 5995        5995  Returning champion Klay Thompson headlines JBL...
# 5996        5996  Aaron Gordon, DeAndre Jordan Headline 2017 Ver...
# 5997        5997    Keys to the Game: Bulls vs. Warriors (03.02.17)
# 5998        5998  Hornets Acquire Center Miles Plumlee From Buck...
# 5999        5999  Joel Embiid, Marquese Chriss named Rookies Of ...
#
#                    time                                                url  \
# 0     November 24, 2018  http://global.nba.com/news/warriors-stephen-cu...
# 1     November 24, 2018  http://global.nba.com/news/pelicans-anthony-da...
# 2     November 24, 2018  http://global.nba.com/news/rockets-to-rest-chr...
# 3     November 24, 2018  http://global.nba.com/news/warriors-looking-to...
# 4     November 24, 2018  http://global.nba.com/news/bucks-end-homestand...
# ...                 ...                                                ...
# 5995   February 2, 2017  http://global.nba.com/news/returning-champion-...
# 5996   February 2, 2017  http://global.nba.com/news/aaron-gordon-deandr...
# 5997   February 2, 2017  http://global.nba.com/news/keys-to-the-game-bu...
# 5998   February 2, 2017  http://global.nba.com/news/hornets-acquire-cen...
# 5999   February 2, 2017  http://global.nba.com/news/joel-embiid-marques...
#
#                    author credit_article credit_followers credit_tweets
# 0                NBA News        Default          Default       Default
# 1                NBA News        Default          Default       Default
# 2                NBA News        Default          Default       Default
# 3                NBA News        Default          Default       Default
# 4                NBA News        Default          Default       Default
# ...                   ...            ...              ...           ...
# 5995             NBA News        Default          Default       Default
# 5996             NBA News        Default          Default       Default
# 5997          Matt Moreno           None             None          None
# 5998  Quinton Pierre-Wash           None             None          None
# 5999             NBA News        Default          Default       Default
#
# [6000 rows x 8 columns]

# %%
news_1600_author_cedit_1 = add_credit(news_1600_author_1)
# Out:
#  28%|██▊       | 1211/4396 [03:32<09:17,  5.71it/s]

# %%
news_1600_author_cedit_1.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/author_credit_nba/news_1600_author_credit_bb.csv', index=False)
