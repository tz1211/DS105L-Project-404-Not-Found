# %%
import pandas as pd

# %%
df10= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2010_5.csv')
df11= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2011_5.csv')
df12= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2012_5.csv')
df13= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2013_5.csv')
df14= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2014_5.csv')
df15= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2015_5.csv')
df16= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2016_5.csv')
df17= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2017_5.csv')
df18= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2018_5.csv')
df19= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2019_5.csv')
df20= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2020_5.csv')
df21= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2021_5.csv')
df22= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2022_5.csv')
df23= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2023_5.csv')

# %%
df16= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_data/bbc_seperate/bbc_2016_5.csv')

# %%
df_10= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2010_3.csv')
df_11= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2011_3.csv')
df_12= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2012_3.csv')
df_13= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2013_3.csv')
df_14= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2014_3.csv')
df_15= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2015_3.csv')
df_16= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2016_3.csv')
df_17= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2017_3.csv')
df_18= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2018_3.csv')
df_19= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2019_3.csv')
df_20= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2020_3.csv')
df_21= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2021_3.csv')
df_22= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2022_3.csv')
df_23= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2023_3.csv')

# %%
df10["relevance_score"] = df_10["relevance_score"]
df11["relevance_score"] = df_11["relevance_score"]
df12["relevance_score"] = df_12["relevance_score"]
df13["relevance_score"] = df_13["relevance_score"]
df14["relevance_score"] = df_14["relevance_score"]
df15["relevance_score"] = df_15["relevance_score"]
df16["relevance_score"] = df_16["relevance_score"]
df17["relevance_score"] = df_17["relevance_score"]
df18["relevance_score"] = df_18["relevance_score"]
df19["relevance_score"] = df_19["relevance_score"]
df20["relevance_score"] = df_20["relevance_score"]
df21["relevance_score"] = df_21["relevance_score"]
df22["relevance_score"] = df_22["relevance_score"]
df23["relevance_score"] = df_23["relevance_score"]

# %%
df16["relevance_score"] = df_16["relevance_score"]

# %%
df10.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2010_FN.csv', index=False)
df11.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2011_FN.csv', index=False)
df12.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2012_FN.csv', index=False)
df13.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2013_FN.csv', index=False)
df14.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2014_FN.csv', index=False)
df15.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2015_FN.csv', index=False)
df16.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2016_FN.csv', index=False)
df17.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2017_FN.csv', index=False)
df18.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2018_FN.csv', index=False)
df19.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2019_FN.csv', index=False)
df20.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2020_FN.csv', index=False)
df21.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2021_FN.csv', index=False)
df22.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2022_FN.csv', index=False)
df23.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2023_FN.csv', index=False)

# %%
df16.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_data/bbc_seperate/bbc_2016_FN.csv', index=False)

# %%
import pandas as pd

def preprocess_dataframe(df):
# Group the dataframe by time and most_frequent_name
    grouped_df = df.groupby(['date', 'player'])
    # Create a new dataframe to store the processed data
    processed_df = pd.DataFrame()

    # Iterate over each group (unique time and most_frequent_name combination)
    for (time, most_frequent_name), group in grouped_df:
        # Print the columns present in the group
        print(f"Columns in group: {group.columns.tolist()}")


        # Calculate average scores for sentiment columns
        average_scores = group[['textblob_sentiment', 'sentiment_bert_average_score',
                                'sentiment_xlnet_average_score', 'bert_relevance',
                                'relevance_score']].mean()

        # Count the number of articles
        num_articles = len(group)

        # Create a new row with processed data
        new_row = {
            'time': time,
            'most_frequent_name': most_frequent_name,
            'url': group['url'].tolist(),
            'textblob_sentiment': average_scores['textblob_sentiment'],
            'sentiment_bert_average_score': average_scores['sentiment_bert_average_score'],
            'sentiment_xlnet_average_score': average_scores['sentiment_xlnet_average_score'],
            'bert_relevance': average_scores['bert_relevance'],
            'relevance_score': average_scores['relevance_score'],
            'frequency': num_articles
        }

        # Append the new row to the processed dataframe
        processed_df = processed_df.append(new_row, ignore_index=True)

    return processed_df

# %%
preprocess_dataframe(df16).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_data/bbc_seperate/bbc_2016_unique.csv', index=False)
# Out:
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# ...

# %%
preprocess_dataframe(df16)
# Out:
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# ...

# %%
preprocess_dataframe(df10).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2010_unique.csv', index=False)
# Out:
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# ...

# %%
preprocess_dataframe(df11).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2011_unique.csv', index=False)
preprocess_dataframe(df12).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2012_unique.csv', index=False)
preprocess_dataframe(df13).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2013_unique.csv', index=False)
preprocess_dataframe(df14).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2014_unique.csv', index=False)
preprocess_dataframe(df15).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2015_unique.csv', index=False)
preprocess_dataframe(df16).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2016_unique.csv', index=False)
preprocess_dataframe(df17).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2017_unique.csv', index=False)
preprocess_dataframe(df18).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2018_unique.csv', index=False)
preprocess_dataframe(df19).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2019_unique.csv', index=False)
preprocess_dataframe(df20).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2020_unique.csv', index=False)
preprocess_dataframe(df21).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2021_unique.csv', index=False)
preprocess_dataframe(df22).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2022_unique.csv', index=False)
preprocess_dataframe(df23).to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_seperate/bbc_2023_unique.csv', index=False)
# Out:
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# Columns in group: ['title', 'date', 'url', 'player', 'textblob_sentiment', 'sentiment_bert_average_score', 'sentiment_xlnet_average_score', 'bert_relevance', 'relevance_score']
# ...
