# %%
import pandas as pd

# %%
df10= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2010_seperate_assessed_4.csv')
df11= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2011_seperate_assessed_4.csv')
df12= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2012_seperate_assessed_4.csv')
df13= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2013_seperate_assessed_4.csv')
df14= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2014_seperate_assessed_4.csv')
df15= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2015_seperate_assessed_4.csv')
df16= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2016_seperate_assessed_4.csv')
df17= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2017_seperate_assessed_4.csv')
df18= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2018_seperate_assessed_4.csv')
df19= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2019_seperate_assessed_4.csv')

# %%
df19
# Out:
#     Unnamed: 0                                              title     date  \
# 0          352  Kobe Bryant drops Â£3.71m to stay at LA Lakers...  2013-14
# 1          790  LeBron James in talks on David Beckham Miami M...  2013-14
# 2         1072                   LV=Cup: Scarlets 13-7 Gloucester  2013-14
# 3         1250  Glasgow 2014: The Jamaican university that cha...  2013-14
# 4         1741  Coach Stephen Keshi proud of Nigeria's CHAN ca...  2013-14
# ..         ...                                                ...      ...
# 60       10920  Champions League draw: Man Utd v Bayern Munich...  2013-14
# 61       10945  Atletico Madrid: Diego Simeone's side are ster...  2013-14
# 62       10955  World Cup 2014: Belgium legends rule out glory...  2013-14
# 63       10995  Gossip column: Kroos, Rodriguez, Casillas, Azm...  2013-14
# 64       11011  Champions League draw: Bayern Munich & PSG fac...  2013-14
#
# ...

# %%
all_df10= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2010_seperate_assessed_6.csv')
all_df11= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2011_seperate_assessed_6.csv')
all_df12= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2012_seperate_assessed_6.csv')
all_df13= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2013_seperate_assessed_6.csv')
all_df14= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2014_seperate_assessed_6.csv')
all_df15= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2015_seperate_assessed_6.csv')
all_df16= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2016_seperate_assessed_6.csv')
all_df17= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2017_seperate_assessed_6.csv')
all_df18= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2018_seperate_assessed_6.csv')
all_df19= pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2019_seperate_assessed_6.csv')

# %%
all_df10["nltk_Sentiment"] = df10["nltk_Sentiment"]
all_df11["nltk_Sentiment"] = df11["nltk_Sentiment"]
all_df12["nltk_Sentiment"] = df12["nltk_Sentiment"]
all_df13["nltk_Sentiment"] = df13["nltk_Sentiment"]
all_df14["nltk_Sentiment"] = df14["nltk_Sentiment"]
all_df15["nltk_Sentiment"] = df15["nltk_Sentiment"]
all_df16["nltk_Sentiment"] = df16["nltk_Sentiment"]
all_df17["nltk_Sentiment"] = df17["nltk_Sentiment"]
all_df18["nltk_Sentiment"] = df18["nltk_Sentiment"]
all_df19["nltk_Sentiment"] = df19["nltk_Sentiment"]

# %%
all_df10.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2010_seperate_assessed_FN.csv', index=False)
all_df11.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2011_seperate_assessed_FN.csv', index=False)
all_df12.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2012_seperate_assessed_FN.csv', index=False)
all_df13.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2013_seperate_assessed_FN.csv', index=False)
all_df14.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2014_seperate_assessed_FN.csv', index=False)
all_df15.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2015_seperate_assessed_FN.csv', index=False)
all_df16.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2016_seperate_assessed_FN.csv', index=False)
all_df17.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2017_seperate_assessed_FN.csv', index=False)
all_df18.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2018_seperate_assessed_FN.csv', index=False)
all_df19.to_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/bbc_news_seperate/bbc_2019_seperate_assessed_FN.csv', index=False)
