# %%
import pandas as pd

# %%
df_nba = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_author_credit/nba_2020_unique.csv')

# %%
df_nba.drop('Unnamed: 0', axis=1, inplace=True)
df_nba.drop('url', axis=1, inplace=True)

# %%
df_nba_1 = df_nba.loc [: 10 ]
md_nba = df_nba_1.to_markdown ( )

# %%
file_path = '/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/github_MDtable/md_nba.md'

with open(file_path, 'w') as file:
    file.write(md_nba)

# %%
df_nba_credibility = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_author_credit/nba_2020_4.csv')

# %%
df_nba_credibility.drop('relevance_score', axis=1, inplace=True)

# %%
df_nba_credibility
# Out:
#                                                   title  time  \
# 0              NBA Suspends Season Until Further Notice  2020
# 1     Giannis Antetokounmpo Feared His Knee Injury W...  2020
# 2             Warriors Statement On Chase Center Events  2020
# 3                     4 NBA Things To Know For March 11  2020
# 4     Lakers Miss Late Opportunity, Nets Take 104-10...  2020
# ...                                                 ...   ...
# 1614  VanVleet & Siakam Both Score 34, Raptors Top P...  2020
# 1615  NBA Icon Dwyane Wade Joins WarnerMedia In Wide...  2020
# 1616  Steve Kerr: ‘Unlikely’ Klay Thompson Plays Thi...  2020
# 1617  108 International Players From 38 Countries On...  2020
# 1618               Six Things To Know For Opening Night  2020
#
#                                  author credit_article credit_followers  \
# 0                      OFFICIAL RELEASE           None             None
# 1     Steve Megargee | Associated Press         124794             1906
# ...

# %%
df_nba_credibility_1 = df_nba_credibility.loc [22 : 33 ]
df_nba_credibility_1_md = df_nba_credibility_1.to_markdown ()

# %%
file_path = '/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/github_MDtable/df_nba_credibility.md'

with open(file_path, 'w') as file:
    file.write(df_nba_credibility_1_md)

# %%
df_nba_credibility_add = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_author_credit/nba_added_2020.csv')

# %%
df_nba_credibility_add.drop('nltk_Sentiment', axis=1, inplace=True)
df_nba_credibility_add.drop('most_frequent_name', axis=1, inplace=True)
df_nba_credibility_add.drop('relevance_score', axis=1, inplace=True)
df_nba_credibility_add.drop('bert_relevance', axis=1, inplace=True)

# %%
df_nba_credibility_add.drop('textblob_Sentiment', axis=1, inplace=True)

# %%
df_nba_credibility_add_1 = df_nba_credibility_add.loc [22 : 33 ]
df_nba_credibility_add_1_md = df_nba_credibility_add_1.to_markdown ()

file_path = '/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_data/github_MDtable/df_nba_credibility_added.md'

with open(file_path, 'w') as file:
    file.write(df_nba_credibility_add_1_md)

# %%
df_nba_f = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_data/nba_author_credit/nba_2020_unique.csv')

# %%
df_nba_f.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_nba_f.drop('url', axis=1, inplace=True)

# %%
df_nba_f
# Out:
#     time most_frequent_name  textblob_Sentiment  nltk_Sentiment  \
# 0   2020       Aaron Gordon            0.092311        0.092311
# 1   2020         Al Horford            0.051690        0.051690
# 2   2020     Andre Drummond            0.036939        0.036939
# 3   2020     Andrew Wiggins            0.090402        0.090402
# 4   2020      Anthony Davis            0.120779        0.120779
# ..   ...                ...                 ...             ...
# 69  2020      Tobias Harris            0.094988        0.094988
# 70  2020         Trae Young            0.080657        0.080657
# 71  2020       Trevor Ariza            0.011409        0.011409
# 72  2020        Will Barton            0.099697        0.099697
# 73  2020        Zach LaVine            0.066251        0.066251
#
#     relevance_score  bert_relevance  credit_article  credit_followers  \
# 0          0.131483        0.567671    39434.800000      34372.600000
# ...

# %%
df_nba_f_md = df_nba_f.to_markdown ()

file_path = '/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_data/github_MDtable/df_nba_final.md'

with open(file_path, 'w') as file:
    file.write(df_nba_f_md)

# %%
df_bbc_unique = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_data/bbc_seperate/bbc_2023_unique.csv')
df_bbc_unique.drop('url', axis=1, inplace=True)

# %%
df_bbc_unique_md = df_bbc_unique.to_markdown ()

# %%
file_path = '/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/news_data/github_MDtable/df_bbc_2023.md'

with open(file_path, 'w') as file:
    file.write(df_bbc_unique_md)
