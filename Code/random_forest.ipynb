# %%
import pandas as pd 
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Import Data

# %%
df_final = pd.read_csv("../Data/final_cleaned_data.csv")
df_final.drop("Unnamed: 0", axis = 1, inplace = True) 
df_final
# Out:
#       season       slug               name                    team  age  \
# 0       2010  aldrila01  LaMarcus Aldridge  PORTLAND TRAIL BLAZERS   24
# 1       2010  allenra02          Ray Allen          BOSTON CELTICS   34
# 2       2010  anthoca01    Carmelo Anthony          DENVER NUGGETS   25
# 3       2010  arenagi01     Gilbert Arenas      WASHINGTON WIZARDS   28
# 4       2010  arizatr01       Trevor Ariza         HOUSTON ROCKETS   24
# ...      ...        ...                ...                     ...  ...
# 1211    2022  westbru01  Russell Westbrook      LOS ANGELES LAKERS   33
# 1212    2022  whitede01      Derrick White       SAN ANTONIO SPURS   27
# 1213    2022  wiggian01     Andrew Wiggins   GOLDEN STATE WARRIORS   26
# 1214    2022   woodch01     Christian Wood         HOUSTON ROCKETS   26
# 1215    2022  youngtr01         Trae Young           ATLANTA HAWKS   23
#
#       %games_played  minutes_played     points   assists  \
# 0          0.951220       37.461538  17.858974  2.051282
# 1          0.975610       35.237500  16.300000  2.625000
# 2          0.841463       38.173913  28.159420  3.217391
# 3          0.390244       36.531250  22.562500  7.187500
# 4          0.878049       36.513889  14.888889  3.833333
# ...             ...             ...        ...       ...
# 1211       0.951220       34.333333  18.474359  7.051282
# 1212       0.597561       30.326531  14.408163  5.591837
# 1213       0.890244       31.904110  17.205479  2.205479
# 1214       0.829268       30.794118  17.911765  2.279412
# 1215       0.926829       34.894737  28.355263  9.697368
#
#       attempted_field_goals  ...  turnover_percentage  usage_percentage  \
# 0                 14.987179  ...                  7.4              22.9
# 1                 12.162500  ...                 10.6              20.2
# 2                 21.768116  ...                 10.6              33.4
# 3                 19.250000  ...                 14.2              31.9
# 4                 13.875000  ...                 12.8              21.2
# ...                     ...  ...                  ...               ...
# 1211              15.807692  ...                 17.3              27.3
# 1212              11.632653  ...                 12.0              20.7
# 1213              13.958904  ...                  9.0              23.1
# 1214              12.911765  ...                 11.0              23.3
# 1215              20.315789  ...                 14.5              34.4
#
#       value_over_replacement_player  win_shares_per_48_minutes  win_rate  \
# 0                               2.3                      0.145  0.609756
# 1                               2.3                      0.135  0.609756
# 2                               2.9                      0.145  0.646341
# 3                               1.1                      0.072  0.317073
# 4                               1.7                      0.058  0.512195
# ...                             ...                        ...       ...
# 1211                            0.2                      0.030  0.402439
# 1212                            1.4                      0.107  0.414634
# 1213                            1.4                      0.105  0.646341
# 1214                            1.9                      0.112  0.243902
# 1215                            4.8                      0.181  0.524390
#
#       conference_standing  num_mvp  won_last_yr  won_2_yrs_before  is_mvp
# 0                       6        0            0                 0       0
# 1                       4        0            0                 0       0
# 2                       4        0            0                 0       0
# 3                      14        0            0                 0       0
# 4                       9        0            0                 0       0
# ...                   ...      ...          ...               ...     ...
# 1211                   11        1            0                 0       0
# 1212                   10        0            0                 0       0
# 1213                    3        0            0                 0       0
# 1214                   15        0            0                 0       0
# 1215                    9        0            0                 0       0
#
# [1216 rows x 48 columns]

# %%
df_2023 = pd.read_csv("../Data/player_data_2023.csv")
df_2023.drop("Unnamed: 0", axis = 1, inplace = True) 
df_2023
# Out:
#      season       slug                   name                   team  age  \
# 0      2023  adebaba01            Bam Adebayo             MIAMI HEAT   25
# 1      2023  allenja01          Jarrett Allen    CLEVELAND CAVALIERS   24
# 2      2023  antetgi01  Giannis Antetokounmpo        MILWAUKEE BUCKS   28
# 3      2023  anunoog01             OG Anunoby        TORONTO RAPTORS   25
# 4      2023  aytonde01          Deandre Ayton           PHOENIX SUNS   24
# ..      ...        ...                    ...                    ...  ...
# 100    2023  washipj01        P.J. Washington      CHARLOTTE HORNETS   24
# 101    2023  westbru01      Russell Westbrook   LOS ANGELES CLIPPERS   34
# 102    2023  wiggian01         Andrew Wiggins  GOLDEN STATE WARRIORS   27
# 103    2023  willizi01        Zion Williamson   NEW ORLEANS PELICANS   22
# 104    2023  youngtr01             Trae Young          ATLANTA HAWKS   24
#
#      %games_played  minutes_played     points    assists  \
# 0         0.918919       35.132353  21.058824   3.279412
# 1         0.837838       33.032258  14.354839   1.677419
# 2         0.777778       32.500000  31.250000   5.571429
# 3         0.794521       35.724138  16.775862   1.896552
# 4         0.847222       30.442623  18.311475   1.819672
# ..             ...             ...        ...        ...
# 100       0.931507       32.867647  15.088235   2.338235
# 101       0.150685       30.363636  13.090909   7.818182
# 102       0.500000       32.162162  17.108108   2.297297
# 103       0.402778       32.965517  26.000000   4.586207
# 104       0.876712       34.875000  26.734375  10.031250
#
#      attempted_field_goals  ...  offensive_rebound_percentage  \
# 0                15.250000  ...                           7.8
# 1                 9.225806  ...                          11.1
# 2                20.392857  ...                           7.5
# 3                13.103448  ...                           4.2
# 4                13.557377  ...                           9.5
# ..                     ...  ...                           ...
# 100              13.000000  ...                           3.1
# 101              11.545455  ...                           4.7
# 102              14.297297  ...                           5.7
# 103              16.172414  ...                           6.8
# 104              19.609375  ...                           2.5
#
#      player_efficiency_rating  steal_percentage  three_point_attempt_rate  \
# 0                        20.4               1.7                     0.012
# 1                        19.8               1.3                     0.016
# 2                        28.6               1.1                     0.137
# 3                        14.4               2.7                     0.401
# 4                        20.3               0.9                     0.029
# ..                        ...               ...                       ...
# 100                      12.4               1.3                     0.440
# 101                      14.0               2.1                     0.260
# 102                      14.8               1.8                     0.425
# 103                      25.3               1.6                     0.041
# 104                      22.5               1.5                     0.333
#
#      total_rebound_percentage  true_shooting_percentage  turnover_percentage  \
# 0                        15.5                     0.595                 12.8
# 1                        17.5                     0.673                 11.6
# 2                        18.9                     0.602                 13.1
# 3                         8.0                     0.586                 13.1
# 4                        18.5                     0.616                 10.9
# ..                        ...                       ...                  ...
# 100                       7.8                     0.538                  9.6
# 101                       9.5                     0.514                 23.1
# 102                       8.6                     0.564                  7.9
# 103                      11.9                     0.652                 14.6
# 104                       4.8                     0.573                 14.9
#
#      usage_percentage  value_over_replacement_player  \
# 0                25.5                            2.3
# 1                16.3                            2.2
# 2                38.7                            4.7
# 3                19.6                            1.1
# 4                23.4                            1.5
# ..                ...                            ...
# 100              19.8                            0.2
# 101              23.8                            0.0
# 102              21.5                            0.4
# 103              30.3                            1.8
# 104              33.1                            3.2
#
#      win_shares_per_48_minutes
# 0                        0.142
# 1                        0.204
# 2                        0.204
# 3                        0.085
# 4                        0.150
# ..                         ...
# 100                      0.048
# 101                      0.033
# 102                      0.087
# 103                      0.175
# 104                      0.128
#
# [105 rows x 42 columns]

# %% [markdown]
# # Random Forest Algorithm

# %% [markdown]
# ## Back testing using historic data

# %%
def predict_mvp(df_id, train_x, train_y, test_x, display = 5, to_print=False): 
    random_forest = RandomForestClassifier() 
    random_forest.fit(train_x, train_y) 
    probs = random_forest.predict_proba(test_x) 
    mvp_prob = probs[:, 1] 
    mvp_prob = np.vectorize(lambda x: x/sum(mvp_prob))(mvp_prob) # Normalising so the probabilities sum up to 1 for a given season 

    df_id["probability"] = mvp_prob 
    df_results = df_id.sort_values("probability", ascending=False)
    df_results = df_results[df_results["probability"] > 0]

    if to_print: 
        print(df_results.iloc[:display, :])

    return random_forest

# %%
for season in range(2010, 2023): 
    df_test = df_final[df_final["season"] == season] 
    df_train = df_final[df_final["season"] != season] 
    df_id = df_test.iloc[:, :5]
    df_id.drop("slug", axis = 1, inplace=True)

    train_x = df_train.iloc[:, 5:-1]
    train_y = df_train.iloc[:, -1] 
    test_x = df_test.iloc[:, 5:-1]

    predict_mvp(df_id, train_x, train_y, test_x, to_print=True)
    print("")
# Out:
#     season               name                   team  age  probability
# 55    2010       LeBron James    CLEVELAND CAVALIERS   25     0.878505
# 32    2010       Kevin Durant  OKLAHOMA CITY THUNDER   21     0.046729
# 18    2010        Kobe Bryant     LOS ANGELES LAKERS   31     0.018692
# 79    2010         Chris Paul    NEW ORLEANS HORNETS   24     0.018692
# 91    2010  Amar'e Stoudemire           PHOENIX SUNS   27     0.009346
#
#      season           name           team  age  probability
# 156    2011   LeBron James     MIAMI HEAT   26          0.6
# 153    2011  Dwight Howard  ORLANDO MAGIC   25          0.4
#
#      season          name                   team  age  probability
# 249    2012  LeBron James             MIAMI HEAT   27     0.702381
# 274    2012  Derrick Rose          CHICAGO BULLS   23     0.119048
# 268    2012   Tony Parker      SAN ANTONIO SPURS   29     0.059524
# 216    2012   Kobe Bryant     LOS ANGELES LAKERS   33     0.035714
# 226    2012  Kevin Durant  OKLAHOMA CITY THUNDER   23     0.023810
#
#      season          name                   team  age  probability
# 334    2013  LeBron James             MIAMI HEAT   28     0.508380
# 312    2013  Kevin Durant  OKLAHOMA CITY THUNDER   24     0.245810
# 360    2013    Chris Paul   LOS ANGELES CLIPPERS   27     0.150838
# 296    2013   Earl Barron        NEW YORK KNICKS   31     0.033520
# 376    2013   Dwyane Wade             MIAMI HEAT   31     0.011173
#
#      season           name                    team  age  probability
# 417    2014   Kevin Durant   OKLAHOMA CITY THUNDER   25     0.666667
# 453    2014     Kevin Love  MINNESOTA TIMBERWOLVES   25     0.106667
# 441    2014   LeBron James              MIAMI HEAT   29     0.106667
# 410    2014  Stephen Curry   GOLDEN STATE WARRIORS   25     0.026667
# 464    2014    Joakim Noah           CHICAGO BULLS   28     0.026667
#
#      season               name                   team  age  probability
# 521    2015       Kevin Durant  OKLAHOMA CITY THUNDER   26     0.333333
# 515    2015      Stephen Curry  GOLDEN STATE WARRIORS   26     0.333333
# 580    2015  Russell Westbrook  OKLAHOMA CITY THUNDER   26     0.106667
# 516    2015      Anthony Davis   NEW ORLEANS PELICANS   21     0.080000
# 563    2015         Chris Paul   LOS ANGELES CLIPPERS   29     0.053333
#
#      season              name                   team  age  probability
# 605    2016     Stephen Curry  GOLDEN STATE WARRIORS   27     0.644628
# 611    2016      Kevin Durant  OKLAHOMA CITY THUNDER   27     0.214876
# 627    2016      James Harden        HOUSTON ROCKETS   26     0.049587
# 603    2016  DeMarcus Cousins       SACRAMENTO KINGS   25     0.024793
# 644    2016     Kawhi Leonard      SAN ANTONIO SPURS   24     0.024793
#
#      season               name                   team  age  probability
# 756    2017  Russell Westbrook  OKLAHOMA CITY THUNDER   28     0.473684
# 702    2017       Kevin Durant  GOLDEN STATE WARRIORS   28     0.118421
# 713    2017       James Harden        HOUSTON ROCKETS   27     0.092105
# 748    2017      Isaiah Thomas         BOSTON CELTICS   27     0.078947
# 697    2017      Stephen Curry  GOLDEN STATE WARRIORS   28     0.065789
#
#      season           name                   team  age  probability
# 803    2018   James Harden        HOUSTON ROCKETS   28     0.666667
# 814    2018   LeBron James    CLEVELAND CAVALIERS   33     0.151515
# 786    2018  Anthony Davis   NEW ORLEANS PELICANS   24     0.045455
# 785    2018  Stephen Curry  GOLDEN STATE WARRIORS   29     0.045455
# 808    2018  Dwight Howard      CHARLOTTE HORNETS   32     0.015152
#
#      season                   name                   team  age  probability
# 883    2019           James Harden        HOUSTON ROCKETS   29     0.570312
# 852    2019  Giannis Antetokounmpo        MILWAUKEE BUCKS   24     0.328125
# 864    2019          Anthony Davis   NEW ORLEANS PELICANS   25     0.023438
# 863    2019          Stephen Curry  GOLDEN STATE WARRIORS   30     0.015625
# 866    2019            Luka Dončić       DALLAS MAVERICKS   19     0.015625
#
#      season                   name                    team  age  probability
# 936    2020  Giannis Antetokounmpo         MILWAUKEE BUCKS   25     0.505747
# 968    2020           James Harden         HOUSTON ROCKETS   30     0.172414
# 986    2020         Damian Lillard  PORTLAND TRAIL BLAZERS   29     0.103448
# 981    2020           LeBron James      LOS ANGELES LAKERS   35     0.045977
# 980    2020           Kyrie Irving           BROOKLYN NETS   27     0.034483
#
#       season                   name                   team  age  probability
# 1076    2021           Nikola Jokić         DENVER NUGGETS   25     0.605042
# 1043    2021          Stephen Curry  GOLDEN STATE WARRIORS   32     0.092437
# 1049    2021            Joel Embiid     PHILADELPHIA 76ERS   26     0.075630
# 1023    2021  Giannis Antetokounmpo        MILWAUKEE BUCKS   26     0.067227
# 1118    2021        Zion Williamson   NEW ORLEANS PELICANS   20     0.033613
#
#       season                   name                team  age  probability
# 1178    2022           Nikola Jokić      DENVER NUGGETS   26     0.440594
# 1123    2022  Giannis Antetokounmpo     MILWAUKEE BUCKS   27     0.336634
# 1154    2022            Joel Embiid  PHILADELPHIA 76ERS   27     0.089109
# 1190    2022              Ja Morant   MEMPHIS GRIZZLIES   22     0.019802
# 1152    2022           Kevin Durant       BROOKLYN NETS   33     0.019802

# %% [markdown]
# ## Predicting 2023 MVP

# %%
df_id = df_2023.iloc[:, :5]
df_id.drop("slug", axis = 1, inplace=True)

train_x = df_final.iloc[:, 5:-1]
train_y = df_final.iloc[:, -1] 
test_x = df_2023.iloc[:, 5:]

# %%
rf_model = predict_mvp(df_id, train_x, train_y, test_x, to_print=True)
# Out:
# /Users/terryzhou/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - conference_standing
# - num_mvp
# - win_rate
# - won_2_yrs_before
# - won_last_yr
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/terryzhou/Desktop/DS105L/Project/DS105L-Project/Code/random_forest.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/terryzhou/Desktop/DS105L/Project/DS105L-Project/Code/random_forest.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> rf_model = predict_mvp(df_id, train_x, train_y, test_x, to_print=True)
#
# /Users/terryzhou/Desktop/DS105L/Project/DS105L-Project/Code/random_forest.ipynb Cell 11 in predict_mvp(df_id, train_x, train_y, test_x, display, to_print)
#       <a href='vscode-notebook-cell:/Users/terryzhou/Desktop/DS105L/Project/DS105L-Project/Code/random_forest.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> random_forest = RandomForestClassifier()
#       <a href='vscode-notebook-cell:/Users/terryzhou/Desktop/DS105L/Project/DS105L-Project/Code/random_forest.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> random_forest.fit(train_x, train_y)
# ----> <a href='vscode-notebook-cell:/Users/terryzhou/Desktop/DS105L/Project/DS105L-Project/Code/random_forest.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> probs = random_forest.predict_proba(test_x)
#       <a href='vscode-notebook-cell:/Users/terryzhou/Desktop/DS105L/Project/DS105L-Project/Code/random_forest.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> mvp_prob = probs[:, 1]
#       <a href='vscode-notebook-cell:/Users/terryzhou/Desktop/DS105L/Project/DS105L-Project/Code/random_forest.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> mvp_prob = np.vectorize(lambda x: x/sum(mvp_prob))(mvp_prob) # Normalising so the probabilities sum up to 1 for a given season
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:850, in ForestClassifier.predict_proba(self, X)
#     848 check_is_fitted(self)
#     849 # Check data
# --> 850 X = self._validate_X_predict(X)
#     852 # Assign chunk of trees to jobs
#     853 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:579, in BaseForest._validate_X_predict(self, X)
#     576 """
#     577 Validate X whenever one tries to predict, apply, predict_proba."""
#     578 check_is_fitted(self)
# --> 579 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     580 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     581     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 37 features, but RandomForestClassifier is expecting 42 features as input.

# %% [markdown]
# ## Feature Importance

# %%
feature_importances = pd.DataFrame({"var": train_x.columns, "importance": rf_model.feature_importances_}).sort_values('importance', ascending=False)
feature_importances
# Out:
#                                   var  importance
# 36          win_shares_per_48_minutes    0.219587
# 28           player_efficiency_rating    0.140932
# 22                     box_plus_minus    0.122589
# 35      value_over_replacement_player    0.086003
# 26           offensive_box_plus_minus    0.081016
# 23           defensive_box_plus_minus    0.047482
# 10                   made_field_goals    0.028802
# 2                              points    0.025792
# 8                  defensive_rebounds    0.021100
# 20                  assist_percentage    0.019744
# 29                   steal_percentage    0.014729
# 34                   usage_percentage    0.014229
# 32           true_shooting_percentage    0.014208
# 11                   made_free_throws    0.013833
# 31           total_rebound_percentage    0.013115
# 12       made_three_point_field_goals    0.012855
# 5               attempted_free_throws    0.011732
# 1                      minutes_played    0.010619
# 14                     personal_fouls    0.009799
# 6   attempted_three_point_field_goals    0.008182
# 33                turnover_percentage    0.007959
# 7                              blocks    0.007660
# 16                          turnovers    0.007609
# 0                       %games_played    0.007358
# 24       defensive_rebound_percentage    0.006933
# 3                             assists    0.006574
# 15                             steals    0.006499
# 18                        free_throw%    0.005744
# 17                        field_goal%    0.005490
# 25            free_throw_attempt_rate    0.004351
# 30           three_point_attempt_rate    0.003962
# 27       offensive_rebound_percentage    0.003444
# 21                   block_percentage    0.002810
# 13                 offensive_rebounds    0.002701
# 19                               3pt%    0.002424
# 4               attempted_field_goals    0.002132
# 9                       games_started    0.000000
