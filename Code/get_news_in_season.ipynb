# %%
import requests

import pandas as pd

from bs4 import BeautifulSoup

from datetime import datetime

# %% [markdown]
# ---

# %%
#import news data and season duration
df_season = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/season_duration.csv')
df_nba_news_archive = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_news_archive.csv')
#df_nba_news_archive_600 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_news_archive_600.csv')
#df_nba_news_archive_600_1200 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_news_archive_600_1200.csv')
#df_nba_news_archive_1200_1640 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/nba_news_archive_1200_1640.csv')
df_season_use = df_season[-13:]

# %%
#import players for each season
df_2023 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2017-2023/2023_player_data.csv')
df_2022 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2017-2023/2022_player_data.csv')
df_2021 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2017-2023/2021_player_data.csv')
df_2020 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2017-2023/2020_player_data.csv')
df_2019 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2017-2023/2019_player_data.csv')
df_2018 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2017-2023/2018_player_data.csv')
df_2017 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2017-2023/2017_player_data.csv')
df_2016 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2016_player_data.csv')
df_2015 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2015_player_data.csv')
df_2014 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2014_player_data.csv')
df_2013 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2013_player_data.csv')
df_2012 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2012_player_data.csv')
df_2011 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2011_player_data.csv')
df_2010 = pd.read_csv('/Users/annabelitong/desktop/annabel/uni/ds105l/group_project/DS105L-Project/Data/2010-2016/2010_player_data.csv')

# %%
#d_all_news = pd.concat([df_nba_news_archive, df_nba_news_archive_600, df_nba_news_archive_600_1200, df_nba_news_archive_1200_1640])

# %%
df_nba_news_archive
# Out:
#        Unnamed: 0                                              title  \
# 0               0  Bucks’ George Hill Returns To Milwaukee, Encou...
# 1               1  NBA, WNBA Ramp Up Efforts To Get Out The Vote ...
# 2               2  Pat Riley Discusses Heat Future, Plans For Kee...
# 3               3  Report: Amar’e Stoudemire Joins Steve Nash’s C...
# 4               4  ESPN To Host Virtual 2020 NBA Draft Presented ...
# ...           ...                                                ...
# 16390       16390  2015-16 Season Preview Extravaganza | How Will...
# 16391       16391          All NBA League Pass First Team: John Wall
# 16392       16392     All NBA League Pass First Team: Damian Lillard
# 16393       16393  All NBA League Pass First Team: Giannis Anteto...
# 16394       16394   All NBA League Pass First Team: DeMarcus Cousins
#
#                    time                                                url
# 0      October 24, 2020  http://global.nba.com/news/bucks-george-hill-r...
# 1      October 24, 2020  http://global.nba.com/news/nba-wnba-ramp-up-ef...
# 2      October 23, 2020  http://global.nba.com/news/pat-riley-discusses...
# 3      October 23, 2020  http://global.nba.com/news/report-amare-stoude...
# 4      October 22, 2020  http://global.nba.com/news/espn-to-host-virtua...
# ...                 ...                                                ...
# 16390  October 12, 2015  http://global.nba.com/news/2015-16-season-prev...
# 16391  October 12, 2015  http://global.nba.com/news/all-nba-league-pass...
# 16392  October 12, 2015  http://global.nba.com/news/all-nba-league-pass...
# 16393  October 12, 2015  http://global.nba.com/news/all-nba-league-pass...
# 16394  October 12, 2015  http://global.nba.com/news/all-nba-league-pass...
#
# [16395 rows x 4 columns]

# %%
duration_list = list(df_season["duration"])

# %%
df_season
# Out:
#      season                           duration
# 0   1950-51  October 31, 1950 – March 18, 1951
# 1   1951-52  November 1, 1951 – March 16, 1952
# 2   1952-53  October 31, 1952 – March 17, 1953
# 3   1953-54  October 30, 1953 – March 14, 1954
# 4   1954-55  October 30, 1954 – March 14, 1955
# ..      ...                                ...
# 68  2018-19  October 16, 2018 – April 10, 2019
# 69  2019-20  October 22, 2019 – March 11, 2020
# 70  2020-21   December 22, 2020 – May 16, 2021
# 71  2021-22  October 19, 2021 – April 10, 2022
# 72  2022-23   October 18, 2022 – April 9, 2023
#
# [73 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## filter the news

# %%
def filter_news_by_time(news_df, date_duration):
    # Convert 'date' column to datetime format
    news_df['time'] = pd.to_datetime(news_df['time'], format="%B %d, %Y")
    start_string, end_string = date_duration.split(" – ")
    start_string = start_string.strip(_)
    end_string = end_string.strip()
    start_date = datetime.strptime(start_string, "%B %d, %Y")
    end_date = datetime.strptime(end_string, "%B %d, %Y")
    mask = (news_df['time'] >= start_date) & (news_df['time'] <= end_date)
    news_within_duration = news_df.loc[mask]


    return news_within_duration

# %%
import pandas as pd
from datetime import datetime

def add_new_column(df_news, df_seasons):
    df_news['time'] = pd.to_datetime(df_news['time'], format='%B %d, %Y')
    
    df_news['season'] = ''
    
    # Loop through each season in season dataframe
    for i, season_row in df_seasons.iterrows():
        duration_str = season_row['duration'].replace('–', '-')  # replace dashes with hyphens
        try:
            season_start = datetime.strptime(duration_str.split('-')[0].strip(), "%B %d, %Y")
            season_end = datetime.strptime(duration_str.split('-')[1].strip(), "%B %d, %Y")
        except: 
            season_start = datetime.strptime(duration_str.split('-')[0].strip() + ", 1998", "%B %d, %Y")
            season_end = datetime.strptime(duration_str.split('-')[1].strip(), "%B %d, %Y")
        
        mask = (df_news['time'] >= season_start) & (df_news['time'] <= season_end) & (df_news['season'] == '')
        df_news.loc[mask, 'season'] = season_row['season']
    
    return df_news

# %%
pd_all_news_for_duration = df_nba_news_archive.copy()
news_season = add_new_column(pd_all_news_for_duration, df_season)

# %%
news_season
# Out:
#        Unnamed: 0                                              title  \
# 0               0  Bucks’ George Hill Returns To Milwaukee, Encou...
# 1               1  NBA, WNBA Ramp Up Efforts To Get Out The Vote ...
# 2               2  Pat Riley Discusses Heat Future, Plans For Kee...
# 3               3  Report: Amar’e Stoudemire Joins Steve Nash’s C...
# 4               4  ESPN To Host Virtual 2020 NBA Draft Presented ...
# ...           ...                                                ...
# 16390       16390  2015-16 Season Preview Extravaganza | How Will...
# 16391       16391          All NBA League Pass First Team: John Wall
# 16392       16392     All NBA League Pass First Team: Damian Lillard
# 16393       16393  All NBA League Pass First Team: Giannis Anteto...
# 16394       16394   All NBA League Pass First Team: DeMarcus Cousins
#
#             time                                                url season
# 0     2020-10-24  http://global.nba.com/news/bucks-george-hill-r...
# 1     2020-10-24  http://global.nba.com/news/nba-wnba-ramp-up-ef...
# 2     2020-10-23  http://global.nba.com/news/pat-riley-discusses...
# 3     2020-10-23  http://global.nba.com/news/report-amare-stoude...
# 4     2020-10-22  http://global.nba.com/news/espn-to-host-virtua...
# ...          ...                                                ...    ...
# 16390 2015-10-12  http://global.nba.com/news/2015-16-season-prev...
# 16391 2015-10-12  http://global.nba.com/news/all-nba-league-pass...
# 16392 2015-10-12  http://global.nba.com/news/all-nba-league-pass...
# 16393 2015-10-12  http://global.nba.com/news/all-nba-league-pass...
# 16394 2015-10-12  http://global.nba.com/news/all-nba-league-pass...
#
# [16395 rows x 5 columns]

# %%
pd_all_news_for_duration = df_nba_news_archive.copy()
news_2023 = filter_news_by_time(pd_all_news_for_duration, df_season)
news_2022 = filter_news_by_time(pd_all_news_for_duration, duration_list[-2])
news_2021 = filter_news_by_time(pd_all_news_for_duration, duration_list[-3])
news_2020 = filter_news_by_time(pd_all_news_for_duration, duration_list[-4])
news_2019 = filter_news_by_time(pd_all_news_for_duration, duration_list[-5])
news_2018 = filter_news_by_time(pd_all_news_for_duration, duration_list[-6])
news_2017 = filter_news_by_time(pd_all_news_for_duration, duration_list[-7])
news_2016 = filter_news_by_time(pd_all_news_for_duration, duration_list[-8])
news_2015 = filter_news_by_time(pd_all_news_for_duration, duration_list[-9])
news_2014 = filter_news_by_time(pd_all_news_for_duration, duration_list[-10])
news_2013 = filter_news_by_time(pd_all_news_for_duration, duration_list[-11])
news_2012 = filter_news_by_time(pd_all_news_for_duration, duration_list[-12])
news_2011 = filter_news_by_time(pd_all_news_for_duration, duration_list[-13])
news_2010 = filter_news_by_time(pd_all_news_for_duration, duration_list[-14])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb Cell 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> pd_all_news_for_duration = df_nba_news_archive.copy()
# ----> <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> news_2023 = filter_news_by_time(pd_all_news_for_duration, df_season)
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> news_2022 = filter_news_by_time(pd_all_news_for_duration, duration_list[-2])
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a> news_2021 = filter_news_by_time(pd_all_news_for_duration, duration_list[-3])
#
# /Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb Cell 15 in filter_news_by_time(news_df, date_duration)
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> def filter_news_by_time(news_df, date_duration):
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a>     # Convert 'date' column to datetime format
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a>     news_df['time'] = pd.to_datetime(news_df['time'], format="%B %d, %Y")
# ----> <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a>     start_string, end_string = date_duration.split(" – ")
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=4'>5</a>     start_string = start_string.strip(_)
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a>     end_string = end_string.strip()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'split'

# %%
news_2023
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, title, time, url]
# Index: []

# %%
df_season
# Out:
#      season                           duration
# 0   1950-51  October 31, 1950 – March 18, 1951
# 1   1951-52  November 1, 1951 – March 16, 1952
# 2   1952-53  October 31, 1952 – March 17, 1953
# 3   1953-54  October 30, 1953 – March 14, 1954
# 4   1954-55  October 30, 1954 – March 14, 1955
# ..      ...                                ...
# 68  2018-19  October 16, 2018 – April 10, 2019
# 69  2019-20  October 22, 2019 – March 11, 2020
# 70  2020-21   December 22, 2020 – May 16, 2021
# 71  2021-22  October 19, 2021 – April 10, 2022
# 72  2022-23   October 18, 2022 – April 9, 2023
#
# [73 rows x 2 columns]

# %% [markdown]
# # using the url of ladder to get the top 10

# %%
# all name list 
whole_list = [df_2023["name"],
                df_2022["name"],
                df_2021["name"], 
                df_2020["name"],
                df_2019["name"],
                df_2018["name"],
                df_2017["name"],
                df_2016["name"],
                df_2015["name"],
                df_2014["name"],
                df_2013["name"],
                df_2012["name"],
                df_2011["name"],
                df_2010["name"]]

# %%
# function which finds the news contain player
pd_all_news_1 = df_nba_news_archive.copy()
df_list = []
def get_player_news(player_list):
    pd_all_news_2 = pd_all_news_1.copy()
    df_list = []
    for player in player_list:
        try:
            pd_player = pd_all_news_2[pd_all_news_2["title"].str.contains(player, na = False)]
            pd_key = pd_player[pd_player["title"].str.contains("MVP", na = False)]
            rows = pd_key.shape[0]
            new_col = pd.Series([player] * rows, name = 'player')
            pd_key = pd_key.join(new_col)
            df_list.append(pd_key)
        except:
            print(f"No news articles found for player {player}")

    final_df = pd.concat(df_list, ignore_index=True)
    final_df.drop(columns = "Unnamed: 0", inplace = True)
    final_df = final_df[final_df["title"].notna()]
    final_df.reset_index(drop = True, inplace = True)

# %%
credit_article = []
credit_followers = []
credit_tweets = []
for name in df_nba_news_archive["author"]:
    if name == "None":
        credit_article.append(name)
        credit_followers.append(name)
        credit_tweets.append(name)
    if name == "NBA.com Staff" or "NBA News":
        credit_article.append("Default")
        credit_followers.append("Default")
        credit_tweets.append("Default")
    else:
        try:
            player_search = "Keith Langlois".replace(" ", "-")
            url = "https://muckrack.com/" + player_search
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')
            html = soup.find_all('a', attrs={'class':"profile-edit-btn"})
            for line in html:
                if line.text == "See all":
                    span_elem = line.find('span')
                    text_content = span_elem.text.strip()
                    num_articles = int(text_content.split()[0].replace(',', ''))
                    credit_article.append(num_articles)
                else:
                    credit_article.append("None")
            tweet = soup.find_all('p', attrs={'class':"fs-6 mt-0 mb-6"})
            tweet_num = tweet.get_all("strong")
            followers = tweet_num[0].strong.text.replace(',', '')
            tweets = tweet_num[1].strong.text.replace(',', '')

        except:
            if len(credit_followers) < len(credit_article):
                credit_followers.append("None")
            if len(credit_tweets) < len(credit_article):
                credit_tweets.append("None")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'author'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb Cell 19 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> credit_followers = []
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> credit_tweets = []
# ----> <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> for name in df_nba_news_archive["author"]:
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>     if name == "None":
#       <a href='vscode-notebook-cell:/Users/annabelitong/Desktop/Annabel/uni/DS105L/group_project/DS105L-Project/Code/get_news_in_season.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>         credit_article.append(name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'author'

# %%
df_nba_news_archive["credit_article"] = credit_article
df_nba_news_archive["credit_followers"] = credit_followers
df_nba_news_archive["credit_tweets"] = credit_tweets
df_nba_news_archive

# %%
url = "https://en.wikipedia.org/wiki/2020-21_NBA_season"            
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
date_duration = soup.find('th', text='Duration').parent
duration_text = date_duration.find('td', class_='infobox-data')
ul = duration_text.find('ul')
li = ul.find('li')
date_range = li.text

# %%
pd_all_news_for_duration['time'] = pd.to_datetime(pd_all_news_for_duration['time'], format="%B %d, %Y")
pd_all_news_for_duration

# %%
start_string, end_string = "October 18, 2015 – April 9, 2016".split(" – ")

start_date = datetime.strptime(start_string, "%B %d, %Y")
end_date = datetime.strptime(end_string, "%B %d, %Y")
news_within_duration = pd_all_news_for_duration[(pd_all_news_for_duration['time'] <= start_date) & (pd_all_news_for_duration['time'] >= end_date)]

# %%
def filter_news_by_time(news_df, date_duration, season):
    # Convert 'date' column to datetime format
    news_df['time'] = pd.to_datetime(news_df['time'], format="%B %d, %Y")
    start_string, end_string = date_duration.split(" – ")
    start_date = datetime.strptime(start_string, "%B %d, %Y")
    end_date = datetime.strptime(end_string, "%B %d, %Y")
    mask = (news_df['time'] >= start_date) & (news_df['time'] <= end_date)
    news_within_duration = news_df.loc[mask]
    
    # Add season column to the filtered news dataframe
    news_within_duration['season'] = season
    
    return news_within_duration

# %%
a = filter_news_by_time(pd_all_news_for_duration[:3], "October 18, 2015 – April 9, 2016")

# %%
pd_all_news_for_duration[:3]

# %%
df_season_use = df_season[-13:]
df_season_use
